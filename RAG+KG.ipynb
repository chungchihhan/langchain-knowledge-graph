# %% [markdown]
# #### Setup

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.graphs import Neo4jGraph
import os

url = os.getenv("URL")
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")
graph = Neo4jGraph(
    url=url,
    username=username,
    password=password
)

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf")
pages = loader.load_and_split()

# %%
pages
# Out:
# [Document(page_content='資訊整體架構健檢及優化服務\n專案 \n建議書徵求說明書  \n(Request for Proposal )  \n \n \n \n \n \n \n \n108年11月25日\n交通部中華郵政股份有限公司', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 0}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \nI \n交通部中華郵政股份有限公司  \n目錄  \n壹、 概述  ................................ ................................ ................................ ....................  1 \n一、  專案緣起  ................................ ................................ ................................ ...............................  1 \n二、  專案目標  ................................ ................................ ................................ ...............................  1 \n貳、 文件詞彙與用語  ................................ ................................ ................................  2 \n一、  名詞定義  ................................ ................................ ................................ ...............................  2 \n二、  文件用語  ................................ ................................ ................................ ...............................  4 \n參、  專案說明  ................................ ................................ ................................ ............  5 \n一、  專案名稱  ................................ ................................ ................................ ...............................  5 \n二、  專案範圍  ................................ ................................ ................................ ...............................  5 \n三、  專案時程  ................................ ................................ ................................ ...............................  5 \n肆、  交付項目及時程  ................................ ................................ ................................  6 \n一、  交付項目與時程  ................................ ................................ ................................ ...................  6 \n ................................ ................................ ................................ ................................ .........................  6 \n二、  交付方法與數量  ................................ ................................ ................................ ...................  6 \n伍、  資訊系統整體架構現況說明  ................................ ................................ ............  7 \n一、  系統軟硬體環境說明  ................................ ................................ ................................ ...........  7 \n陸、  專案需求  ................................ ................................ ................................ ............  9 \n一、  資訊硬體及系統軟體優化需求  ................................ ................................ ...........................  9 \n二、  資訊安全架構與管理機制優化需求  ................................ ................................ .................  14 \n三、 資訊處雙中心機房環境優化需求  ................................ ................................ .....................  16 \n四、  應用軟體開發優化需求  ................................ ................................ ................................ ..... 17 \n五、  資訊服務對業務發展支援的優化需求  ................................ ................................ .............  19 \n六、  資訊部門人員組織優化需求  ................................ ................................ .............................  20 \n七、 報告說明會需求  ................................ ................................ ................................ .................  22 \n八、 專案品質保證需求  ................................ ................................ ................................ .............  22 \n九、  專案資安需求  ................................ ................................ ................................ .....................  22 \n十、  專案組織與管理需求  ................................ ................................ ................................ .........  22 \n十一、  分包管理需求  ................................ ................................ ................................ .................  25', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \nII  \n交通部中華郵政股份有限公司  \n十二、  專案稽核需求  ................................ ................................ ................................ .................  26 \n十三、  工作說明書需求  ................................ ................................ ................................ .............  27 \n柒、  驗收準則  ................................ ................................ ................................ ..........  28 \n一、  文件驗證準則  ................................ ................................ ................................ .....................  28 \n二、  驗收審查準則  ................................ ................................ ................................ .....................  28 \n捌、  建議書  ................................ ................................ ................................ ..............  29 \n一、  服務建議書製作  ................................ ................................ ................................ .................  29 \n二、  價格建議書製作  ................................ ................................ ................................ .................  31 \n三、  建議書製 作規則(詳招標規範 ) ................................ ................................ .........................  32 \n四、 建議書評選辦法 (詳招標規範 ) ................................ ................................ .........................  32', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n1 \n交通部中華郵政股份有限公司  \n壹、概述 \n一、專案緣起 \n鑑於本公司業務對於資訊系統依賴度不斷增加，另考量未來通路\n與電子支付 發展趨勢，無論由實體到虛擬，由支局到網路再到雲\n端，甚至於電子行動業務，要求 7x24小時不中斷服務作業的壓力\n與日俱增；爰透過 第三方專業諮詢團隊針對本公司資訊整體架構\n進行健檢 ，並提出 優化方向與方案建議 ，以強化資訊作業品質，\n降低資訊作業風險，提升資訊組織效率，提供顧客穩定、安全及\n優質金融資訊服務，進而提升 公司營運綜效及創造企業價值。  \n二、專案目標  \n(一) 蒐集並查訪本公司資訊軟硬體架構與管理現況，確認目前資訊\n服務提供情形，並據以分析資訊整體架構 及運作流程 ，提供各\n面向優化方案。  \n(二) 評估並提出適合本公司資訊作業 各面向的 改善建議與方案 ，以\n提供符合本公司經營策略與業務需求且具持續改善能力之服\n務導向資訊變革依據 ，俾強化本公司資訊服務能力，提升服務\n品質，達到降低資訊異常發生頻率、提高資訊 系統運作效能並\n提升資訊 作業維運效率目標 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 3}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n2  \n交通部中華郵政股份有限公司  \n貳、文件詞彙與用語  \n一、名詞定義  \n(一) 開工日 \n係指召開本專案開工會議 (Kick-off Meeting) 當日。 \n(二) 缺失 \n與標準或需求有所不同或不一致的部分稱為缺失\n（Defect） ，本文件中「缺失」用語包含文件中的缺失及程\n式缺失（ Bug） 。程式缺失包括平臺 軟體功能、操作、畫面、\n效能、資訊安全等軟體開發或管理上之預料外行為。缺失可\n以依照其屬性及影響程度，給予不同分類和權值。  \n(三) 嚴重缺失  \n嚴重缺失包含： (1)得標廠商所交付之文件，存在錯誤描\n述、遺漏描述、不符合本公司作業標準的描述或無法執行之\n描述。(2)得標廠商所交付之程式存在缺失，造成系統當機\n或部分系統模組無法使用。嚴重等級缺失之權值應訂為 3。 \n(四) 中度缺失  \n中度缺失包含： (1)得標廠商所交付之文件，存在不清楚或\n不足夠的描述、用語不恰當。 (2)得標廠商所交付之程式存\n在缺失，造成資料處理錯誤、部分系統功能無法使用。中度\n等級缺失之權值應訂為 2。 \n(五) 輕度缺失  \n輕度缺失包含： (1)得標廠商所交付之文件，存在編輯上的\n錯誤。(2)得標廠商所交付之程式存在缺失，造成系統操作\n畫面、報表呈現格式和使用者期望不一致。輕度等級缺失之\n權值應訂為 1。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 4}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n3  \n交通部中華郵政股份有限公司  \n(六) 全部缺失抑制有效性  \n全部缺失抑制有效性（ Total Defect Containment \nEffectiveness, TDCE ）是指由得標廠商所發現的文件或程\n式缺失值， 佔本專案驗證審查文件及測試時得標廠商與本公\n司所發現的總缺失值的比例。公式為  TDCE = I / (I+E) * \n100%，其中I是指由得標廠商發現之文件或程式缺失，經加\n權計算後的缺失值。 E是指本公司對得標廠商所交付之文件\n或程式，審查或測試所發現並經加權計算後的缺失值。  \n(七) 缺失移除效果  \n缺失移除效果 (Defect Removal Effectiveness ，DRE)是指\n得標廠商所交付之文件或程式，移除所有已發現缺失的數\n量，經加權計算後的缺失值， 佔本專案所有加權缺失值的比\n例。DRE=C/(O+C) ，其中， C表示所有被發現且已經 改正的缺\n失值，O表示所有被發現但還沒有 改正的缺失值。  \n(八) 加權缺失密度  \n加權缺失密度 (Weight Defect Density ，WDD)是指計算每一\n缺失依其分類對應之權值，將所有文件缺失和程式缺失分別\n計算其權值總和，文件缺失權值總和除以本專案執行驗證審\n查文件頁數（文件Size，文件提供方式以 Word標楷體字\n型、字大小 14、間距0行、單行行距 ）得到文件加權缺失密\n度。程式缺失權值總和除以本專案軟體規模數 (程式Size)得\n到程式加權缺失密度。假設缺失依其嚴重程度分為 A、B、C\n三類，其權值分別為 a、b、c，缺失數量為 X、Y、Z，則缺\n失密度為 WDD=Σ(XAa+YBb+ZCc)/Size 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 5}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n4  \n交通部中華郵政股份有限公司  \n二、文件用語  \n(一) 時程與時間  \n本文件中有關於「時程」或「時間」的要求，除另有說明或\n特別約定外，均採用日曆天為時程計算依據。例如，簽約後\n30日內完成交付，是指簽訂契約之次日起 30個日曆天 內完\n成交付。  \n(二) 交付 \n本文件中有關於「完成交付」 、 「交付」或「完成」等用語，\n表示得標廠商所交付之服務、文件、紀錄或程式，必須要在\n本文件要求之「時程或時間」送達本公司指定單位或人員。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 6}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n5  \n交通部中華郵政股份有限公司  \n參、專案說明  \n一、專案名稱  \n資訊整體架構健檢及優化 服務專案(以下簡稱本專案 )。 \n二、專案範圍  \n本專案檢視與優化建議 範圍為本公司各項資訊 環境及作業程序，\n且至少包含以下 項目：  \n1. 資訊硬體及系統軟體 。 \n2. 資訊安全。  \n3. 機房環境。  \n4. 軟體開發。  \n5. 資訊服務支援業務發展。  \n6. 資訊部門人員組織。  \n三、專案時程  \n本專案時程分 下列階段，投標廠商須於建議書專案管理規劃中詳\n述各階段時程規劃、工作內容 ： \n(一) 專案前置階段 ：決標次日起 14日內。 \n(二) 開工階段：工作說明書審核認可次日起 7日內。 \n(三) 健檢訪談階段 ：開工次日起 6個月內。  \n(四) 分析與建議階段 ：開工次日起 8個月內。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 7}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n6  \n交通部中華郵政股份有限公司  \n肆、交付項目 及時程  \n一、交付項目與時程 \n項次 活動項目  交付項目  交付時程  \n1 專案前置 階段 工作說明書  決標次日起 14日\n內 \n2 開工階段 1. 辦理開工會議交付 開工報告  \n2. 健檢及優化訪談計畫書  工作說明書審核\n認可次日起 7日\n內 \n※ 第1次驗收 (里程碑) 付款20% \n3 \n健檢訪談 階段 資訊現況報告書  \n 開工次日起 4個\n月內完成 報告書\n交付，並於審核\n認可次日起 14日\n內辦理「資訊現\n況簡報說明」  \n4 1.業管單位訪談 報告書 \n2.資訊整體架構健檢報告書  開工次日起 6個\n月內完成交付  \n5 分析與建議階\n段 資訊整體架構 優化建議報告書  開工次日起 8個\n月內完成交付  \n專案總結簡報  資訊整體架構 優\n化建議報告書審\n核認可次日起 14\n日內辦理 \n※ 最後驗收 (里程碑) 第2次付款80% \n \n二、交付方法與數量  \n(一) 各階段交付文件應以實體書面文件及媒體檔案 (格式為MS \nWord或Open Data )各1份為之，各項報告書經 本公司認可\n後得標廠商 應另交付 10份紙本文件 。 \n(二) 全案驗收時應彙整各階段交付文件，燒錄於光碟媒體，交付\n本公司。   表一、交付項目與時程表', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 8}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n7  \n交通部中華郵政股份有限公司  \n伍、資訊系統整體架構 現況說明  \n一、系統軟硬體環境說明  \n(一)  各區重要設備說明如下：  \n本公司內部網路為 3層式架構，各支局線路匯集至各連線\n設備管理機房後，再連至 臺北資訊處及臺中備援中心。  \n區 域 重要設備  說 明 \n臺北資訊處及  \n臺中備援中心  IBM大型\n主機 為本公司郵、儲、壽等主要業務之核心系統，提供全年\n24小時連線即時服務。目前大部分邏輯分區 (LPAR)均使\n用z/OS 2.1 作業系統，其中包含 IMS、CICS、MQ等子系\n統，以及 IMS/DB、DB2等資料庫；少數邏輯分區使用 SUSE \nLinux 12 作業系統。  \n集中運算\n環境 供本公司對外及對內服務之開放系統伺服器使用，包含\n伺服器、磁碟陣列及儲域網路等，作業系統包括：\nWindows Server 2008 R2 、Windows Server 2012 R2 、\nRedHat Linux 6 ，並可提供 SQL 2008 、SQL 2008 R2 作\n為資料庫使用。  \n網路設備  含路由器、交換器、負載平衡設備等，並已配置 Class A \nx 1、Class B x 3組TCP/IP網段。 \n資安設備  含防火牆、入侵偵測防護系統、 WAF、防毒軟體等。  \n各連線設備管\n理機房 伺服器 含SCCM、AD、防毒等實體伺服器。  \n網路設備  含路由器、交換器等。  \n各支局 主控機 提供臨櫃工作站交易作業閘道服務，並透過內網轉送交\n易至IBM大型主機。目前作業系統使用 Windows 2008 ，\n並安裝本公司委外開發之郵儲壽終端整合平臺 、 Windows \nHIS Server 、SQL Server 等軟體。  \n網路設備  含路由器、交換器等，提供工作站連接內部網路使用。  \n 表二、資訊重要設備列表', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 9}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n8  \n交通部中華郵政股份有限公司  \n(二)  資訊環境 架構圖  \n1. 本公司各業務資訊服務主要由大型主機及集中運算環境伺服器協同運\n作下提供，前者主要提供郵儲壽等核心業務交易，並將資料存放於大\n型主機磁碟機上，後者則用於提供內部員工與外部使用者各種開放環\n境及網際網路應用服務，並將相關資料存放於集中運算環境儲存體與\nSQL資料庫。 \n2. 為有效防範各類資安攻擊行為，本公司因應不同業務屬性資訊系統及\n用途，共劃分非軍事區（ DMZ，Demilitarized Zone） 、測試區、廠商\n開發區、企業網路區、網際網路區、大型主機區及內 部網路區等多個\n不同網路區域，其間以資安設備進行控管。  \n3. 為服務廣大用郵客戶，本公司採用負載平衡設備介接多家電信業者，\n以提供高可用性與流量分流之網際網路 (Internet) 服務；另為連接各\n區設備及線路，本公司使用大量路由器及交換器等網路設備，並透過\n動態計算路由機制達成網路高可用性及分流等機制。  \n台中備援中心  \n圖一、資訊環境架構圖  DWDM', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 10}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n9  \n交通部中華郵政股份有限公司  \n陸、專案需求  \n一、資訊硬體及系統軟體 優化需求  \n資訊硬體及系統軟體共通需求 : \n為提升資訊服務穩定性， 得標廠商應 針對本公司 資訊硬體及系統\n軟體等資訊基礎架構、維運 與管理機制進行檢視及訪談，據以提\n供適合本公司之 改善建議與方案 ，及其與現況差異分析說明， 至\n少提供以下內容：  \n➢ 改善建議與方案 及其與現況差異分析說明 內容範圍至少 包含： \n⚫ 硬體架構  \n⚫ 軟體架構  \n⚫ 備援架構  \n⚫ 能量規劃  \n⚫ 監控規劃  \n⚫ 維運與管理 \n⚫ 人員配置 (含數量、資格、資歷等) \n➢ 所提建議 應提供在現有軟硬體架構下的短期方案， 及完整改善\n之長期方案 ，且各方案應 依標的特性 ，至少對降低資訊異常發\n生頻率、提高資訊系統運作效能 、提升資訊作業維運效率等目\n標有其效益分析 說明，並以可量化效益為佳 。 \n➢ 因應本公司現況與建議方案差異，提供實現各 改善建議與方案\n之費用、人力、時程、風險及先決條件等評估。  \n➢ 未來方向建議 。 \n \n(一)Internet 線路 \n1. 現況與架構說明：  \n本公司對外網站連線服務同時具備 多家不同電信商之網際\n網路資源，且 電信商均至少設置 2條線路，並利用負載平\n衡設備自動分配線路資源。 提供本公司連接網際網路環境\n(含IPv4及IPv6)能力，對外提供公司對外網站 (如網路郵\n局、e動郵局及WebATM等)連線服務，對內提供公司同仁連', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 11}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n10  \n交通部中華郵政股份有限公司  \n線至外部網路服務 (如政府網站、 Google等)使用。 \n2. 共通需求外 其他檢視與評估需求：  \n(1) 檢視本公司 Internet 線路及相關設備配置是否完善。  \n(2) 分析線路頻寬使用情形，並提供適合本公司頻寬需求及\n使用優化。  \n \n(二)負載平衡設備  \n1. 現況與架構說明：  \n(1) 網域名稱解析服務 (DNS)：提供本公司對外網站名稱解\n析服務，使民眾可連接至本公司網站。  \n(2) 網站負載平衡服務：提供單一系統 2臺以上伺服器之資\n源分配，避免單臺伺服器故障造成服務中斷。  \n(3) 負載平衡設備利用高可用性 (HA)技術建置，資訊隨時同\n步，當設備異常時，自動切換至 其他正常之設備。  \n2. 共通需求外其他檢視與評估需求：  \n(1) 檢視DNS網域名稱解析服務 (DNS)及網站負載平衡服務\n內容，並提供強化建議。  \n(2) 檢視負載平衡架構，提供 系統伺服器或負載平衡設備 異\n常之快速恢復方案與 架構建議。 \n \n(三)網路設備  \n1. 現況與架構說明：  \n(1) 連結本公司各項資訊作業節點，如：伺服器、資料庫、\n儲存體及 Mainframe 大型主機等，以提供用郵客戶本公\n司各項資訊服務。  \n(2) 本公司採 3層式網路架構，分別為雙中心 (臺北資訊\n處、臺中備援中心 )、連線設備機房、支局等 3種環境\n配置。 \n2. 共通需求外其他檢視與評估需求：  \n(1) 計畫性作業稽核優化建議 。 \n(2) 障礙排除流程優化建議 。 \n(3) 網路架構與組態優化建議 。 \n(4) 委外人員與配合廠商管理流程優化建議 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 12}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n11  \n交通部中華郵政股份有限公司  \n \n(四)實體伺服器   \n1. 現況與架構說明：  \n提供虛擬伺服器所需資源，如 CPU、記憶體、網路、儲存體\n等，另提供未虛擬化之系統所需資源，如目錄服務管理系\n統、備份系統等。  \n2. 共通需求外其他檢視與評估需求：  \n光纖網路健康及效能評估、優化及管理建議。  \n \n(五)集中運算環境儲存體   \n1. 現況與架構說明：  \n提供開放環境各應用系統儲存空間。  \n2. 共通需求外其他檢視與評估需求：  \n儲存體架構檢視與優化。  \n \n(六)虛擬伺服器   \n1. 現況與架構說明：  \n虛擬伺服器透過 VMware vSphere 建構，提供各應用系統運\n作資源，如虛擬 CPU、記憶體、磁碟空間等。  \n2. 共通需求外其他檢視與評估需求：  \n(1) 虛擬環境健康及效能評估、優化及管理建議。  \n(2) 虛擬資料庫架構檢視與優化。  \n \n(七)中介軟體 (BlueStar 、HIS)  \n1. 現況與架構說明：  \n(1)BlueStar 伺服器：為一單一介面平臺，作為開放系統應\n用程式與大型主機系統間的溝通橋樑，透過定義方式進\n行交易資料的轉換及轉碼作業，目前使用之業務計有外\n匯看板、聯合信用卡預借現金、郵務查詢系統、網路\nATM、網路郵局、交通罰款、鐵路局代售票系統及客服\n系統等業務。  \n(2)HIS伺服器：提供 BlueStar 伺服器介接主機，並進行網\n路協定轉換。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 13}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n12  \n交通部中華郵政股份有限公司  \n(3)BlueStar 與HIS伺服器皆為集中運算環境虛擬伺服器，\n可依需求動態調整配置。另透過負載平衡設備將前端交\n易分散至 多臺 BlueStar 伺服器，並透過 HIS LU Pool\n功能，將上行交易分散於多 臺HIS 伺服器上，達成分流\n及備援機制。  \n2. 共通需求外其他檢視與評估需求：  \n(1) HIS伺服器效能評估與優化建議。  \n(2)因應SNA通訊協定相關支援產品及廠商資源較少， 提供\n與主機網路連線方式 短中長期 規劃與因應方向。 \n \n(八)SQL資料庫 \n1. 現況與架構說明：  \n本公司主要使用 SQL Server 2008 與SQL Server 2016 ，分\n別為多臺 實體伺服器組成叢集架構，以 提供集中運算環境\n存取資料庫服務 。 \n2. 共通需求外其他檢視與評估需求：  \n(1) 優化現行透過 SCOM即時監控系統資源 及效能之 管理機\n制。 \n(2) 須協助評估資料庫因應未來業務發展所需容量空間，或\n提供流程機制以管控現階段及未來所需容量。  \n \n(九)大型主機 (Mainframe)  \n1. 現況與架構說明：  \n(1) 為本公司郵、儲、壽等主要業務之核心系統，提供全年\n24小時連線即時服務。目前大部分邏輯分區 (LPAR)均\n使用z/OS 2.1 作業系統，其中包含 IMS、CICS、MQ等\n子系統，以及 IMS/DB、DB2等資料庫；少數邏輯分區使\n用SUSE Linux 12 作業系統  \n(2) 目前大型主機自成一 DMZ區，並透過 多種資安設備管控\n連線，以確保資訊安全。  \n2. 共通需求外其他檢視與評估需求：  \n(1) 評估大型主機 對本公司業務的適用性及未來本公司之變\n革方向。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 14}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n13  \n交通部中華郵政股份有限公司  \n(2) 須提建議方案 之相關短中長期作法。  \n \n(十)主機磁碟機  \n1. 現況與架構說明：  \n提供大型主機高可靠性及高效能的企業等級儲存環境，目\n前配置臺北 資訊處及臺中備援中心各 2臺主機磁碟機 ，並\n透過其同步 (SRDF/S) 及非同步 (SRDF/A) 抄寫機制，建構 完\n整之同地備援 及異地備援機制，以確保本公司業務營運資\n料完整性與正確性，保障客戶權益。  \n2. 共通需求外其他檢視與評估需求：  \n儲存體架構檢視與優化。  \n \n(十一)作業系統 (z/OS)及子系統  \n1. 現況與架構說明：  \n(1) z/OS作業系統： z/OS係專門運作於大型主機上之作業\n系統，用於提供穩定、安全且高可用性的環境。  \n(2) IMS連線交易系統：運作於 z/OS作業系統上之交易訊\n息處理系統，為本公司主要核心帳務交易系統所使用。  \n(3) CICS連線交易系統：運作於 z/OS作業系統之之交易訊\n息處理系統，為本公司郵務及會計交易系統所使用。  \n2. 共通需求外其他檢視與評估需求：  \n目前主機上作業系統、連線交易系統等相關子系統皆由本\n公司自行維運，因其相關專業技術人員養成不易，已另案\n由廠商提供技術支援。本案須評估現階段廠商管理方式，\n以及評估委外維運之可行性。  \n \n(十二)主機資料庫  \n1. 現況與架構說明：  \n(1) IMS資料庫： 主機上使用之階層式資料庫，為本公司主\n要帳務資料存放所在。  \n(2) DB2資料庫： 主機上使用之關聯式資料庫，為本公司郵\n務及會計資料存放所在。  \n(3) 為預防資料庫因磁碟異常或交易程式異常等原因而損', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 15}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n14  \n交通部中華郵政股份有限公司  \n毀，定時將日誌及資料庫資料備份至磁帶。亦透過大型\n主機磁碟機抄寫功能存放於臺中備援中心，如發生災害\n時，可由臺 中備援中心接手提供資料庫服務。  \n2. 共通需求外其他檢視與評估需求：  \n本案須協助評估資料庫因應未來業務發展所需容量空間，\n或提供流程機制以管控現階段及未來所需容量。  \n \n二、資訊安全 架構與管理機制 優化需求  \n(一)現況與架構說明：  \n    本公司現有資安設備與防護機制項目及架構如下 : \n1. 防毒軟體  \n2. 各式防火牆 \n3. 入侵偵測及防禦機制  \n4. 進階持續性威脅（ APT）攻擊防禦措施  \n5. 資料外洩防護 (Data Loss Prevention, DLP)  \n6. 電子郵件攻擊防護機制  \n7. 阻斷式攻擊防護 (DDoS)機制 \n8. 資安監控系統 (SOC) \n9. 伺服器流量負載平衡設備及寬頻管理', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 16}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n15  \n交通部中華郵政股份有限公司  \n \n(二)檢視與評估需求：  \n針對本公司資安架構、防護作為與管理機制進行檢視及訪\n談，據以 提供適合本公司之 改善建議與方案 ，及其與現況差\n異分析說明， 內容範圍至少包含 ： \n1. 硬體架構  \n2. 軟體架構  \n3. 備援架構  \n4. 能量規劃  \n5. 監控規劃  \n6. 管理與維運  \n7. 同一區域 (如各DMZ區及內部網路 )之防禦機制。  \n8. 端點設備 (如周邊裝置使用 或物聯網設備管理 )管控機制。  \n9.檔案分享 (如網路芳鄰、 USB儲存體)資料安全控管架構與程\n序。 \n10.人員配置 (含數量、資格、資歷等 ) \n圖二、資安環境架構圖', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 17}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n16  \n交通部中華郵政股份有限公司  \n11.所提建議應提供在現有軟硬體架構下的短期方案，及完整\n改善之長期方案，且各方案應依標的特性，至少對降低資\n訊異常發生頻率、提高資訊系統運作效能、提升資訊作業\n維運效率等目標有其效益分析說明，並以可量化效益為\n佳。 \n12.因應本公司現況與差異，提供實現 各改善建議與方案 之費\n用、人力、時程、風險、先決條件等評估。  \n13.其他未來方向建議。  \n \n三、資訊處雙中心機房環境 優化需求  \n(一)現況說明：  \n1. 電力系統  \n(1) 電力系統設備維護保養由勞安單位負責 。 \n(2) 電力系統架構：雙市電或發電機連接至不斷電系統\n(UPS)。 \n2. 空調系統  \n(1) 空調系統設備維護保養由勞安單位負責 。 \n(2) UPS供電。 \n(3) 冰水及冷卻水 2種空調箱。  \n(4) 設置備援機制。  \n3. 消防系統  \n(1) 自動滅火系統。  \n(2) 手提式滅火系統。  \n(3) 極早期偵煙預警系統，偵測異常時以聲音告警。  \n4. 環境監控系統  \n(1) 溫溼度偵測，偵測異常時以聲音告警。  \n(2) 漏水偵測，偵測異常時以聲音告警。  \n(3) CCTV系統。 \n5. 門禁管制系統。  \n(1) 門禁異常時聲音告警。  \n(2) 人員進出視負責業務需要申請權限。  \n(3) 每半年進行權限盤點作業。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 18}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n17  \n交通部中華郵政股份有限公司  \n表三、應用系統概況表  6. 其他 \n  重要資訊設備裝設減震模組。  \n(二)檢視與評估需求：  \n提供資訊機房架構與管理 之改善建議與方案 及其與現況差異\n分析說明 。 \n所提建議應提供在現有軟硬體架構下的短期方案，及完整改\n善之長期方案，且各方案應依標的特性，至少對降低資訊異\n常發生頻率、提高資訊系統運作效能、提升資訊作業維運效\n率等目標有其效益分析說明，並以可量化效益為佳。  \n \n四、應用軟體開發優化需求  \n(一)現況說明：  \n1.本公司主機與開放環境應用 系統軟體 概況如下表  \n \n     系統類型  \n作業性質  主機系統套數  開放系統套數  \n客戶服務  18套 38套 \n作業管理  \n及決策支援  15套 64套 \n系統總套數  135套 \n程式總支數  253,356 支 \n \n2.主機應用系統 現況與架構說明：  \n相關應用系統開發於 IBM Mainframe 主機，使用 PL/I、\nCOBOL及Assembly( 少數系統 )等語言， 介接資料庫有 IMS \nDB及DB2，大部分以自有人力進行 系統開發及維運，少部\n分為委外作業。  \n3.開放環境應用系統 現況與架構說明：  \n本公司應用系統除部分系統分散建置於各使用單位外，其\n餘大多數系統建置於本公司開放式集中運算環境，並依應', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 19}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n18  \n交通部中華郵政股份有限公司  \n用系統類別及屬性建置於各 DMZ區(Demilitarized \nZone)。 \n開放環境應用系統維運現況可分為以下 5類，大部分為委\n外作業，少部分以自有人力進行開發 ，使用.NET C#、.NET \nVB、JAVA、VB、PowerBuilder 等程式語言：  \n(1) 主從式架構 Client-Server系統。 \n(2) 網頁式架構 Web-Based系統  \n(3) 單機版架構系統。  \n(4) 手持式裝置架構系統。  \n(5) 通訊GateWay 架構系統 (無使用者操作介面 )。 \n \n(二)主機與開放環境應用系統軟體 檢視與評估需求：  \n為強化應用系統 開發時程、品質及系統穩定度 ，應針對本公\n司主機與開放環境應用系統架構及運作進行檢視與訪談，並\n提供相關說明與優化建議，內容包含但不限於下列項目 : \n1. 應用系統需求蒐集流程檢視及最佳化建議。  \n2. 應用系統分析設計 (SA)流程檢視及最佳化建議。  \n3. 應用系統開發測試流程檢視及最佳化建議。  \n4. 應用系統品質保證 (QC)作業檢視及最佳化建議。  \n5. 應用系統建置後維運與程序檢視及最佳化建議。  \n6. 應用系統自有及委外人力檢視及最佳化建議。  \n7. 自有人力數量、資格、資歷與養成檢視及最佳化建議。  \n8. 其他未來方向與建議。  \n9. 所提建議應提供配合現有組織及 系統環境下的短期方\n案，及完整改善之長期方案， 且各方案應依標的特性，\n至少對降低資訊異常發生頻率、提高資訊系統運作效\n能、提升資訊作業維運效率等目標有其效益分析說明，\n並以可量化效益為佳。  \n10.因應本公司現況與差異，提供實現各最佳化建議方案之\n費用、人力、時程、風險、先決條件等評估。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 20}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n19  \n交通部中華郵政股份有限公司  \n五、資訊服務對業務發展支援的優化需求  \n資訊單位應負責公司資訊策略規劃 、共用資訊基礎設施與資源 之\n管理、推動資訊安全與標準、 執行資訊系統整體規劃 及辦理資訊\n系統委外作業管理 ，惟相關運作均須與 業務單位協同作業 ，故本\n案應對各業管單位 進行現況與需求訪談 ，據以提供資訊服務對業\n務發展支援的現況分析與優化 作法建議，需求內容包含但不限於\n下述範圍 : \n(一)瞭解本公司郵務、儲匯、壽險、集郵、電商等各業務領域策\n略目標，如數位金融、智慧物流等 ，並據以提供各資訊面向\n最佳因應作為。  \n(二)檢視本公司 業管單位資訊需求規劃 作業流程、 人力與能力 等\n現況，並據以提供業管單位在 業務資訊化時應具備的 條件、\n態度與能力之優化建議 。 \n(三)提出資訊單位在 組織、資源(含人力與能力資源、軟硬體設\n備資源 )、規劃、 開發能力、 作業流程等各資訊服務面向應\n具備的條件、態度 與能力之 優化建議，以因應業務資訊化的\n需求。  \n(四)提供適合本公司 各單位業務需求 使用之資訊成本與 效益評估\n方式，及資訊成本分攤作法。  \n(五)提出適合本公司 資訊單位 與業管單位 協同運作 最佳模式與流\n程，以支援 業務發展 及各項創新服 務。 \n(六)提供適合本公司提出跨單位業務需求、業 管單位間及業 管單\n位與資訊單位間遇意見衝突時之整合與意見協調之 最佳運作\n建議。  \n(七)提供在業務工作計畫有變或因急迫需求須改變計畫時之最佳\n應變、處理 、協調程序與作法。  \n(八)提供資訊 異常事件發生時，資訊單位與業管單位 應變、通\n報、處理與協調之最佳 程序與作法。  \n(九)提供本公司資訊單位與業管單位 快速掌握資訊科技發展方向\n及對新技術迅速學習及應用之最佳作法與建議 。 \n(十)所提建議應提供配合現有組織及系統環境下的短期方案，及', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 21}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n20  \n交通部中華郵政股份有限公司  \n圖三、資訊組織架構圖  完整改善之長期方案，且各方案應依標的特性，至少對降低\n資訊異常發生頻率、提高資訊系統運作效能、提升資訊作業\n維運效率等目標有其效益分析說明，並以可量化效益為佳。  \n(十一)相關資訊面最佳因應作為建議與作法應考量本公司組織與\n定位的獨特性，及在人力取得、法令遵循、業務發展與作業\n流程上的限制 ，並提供實現 各最佳化建議之費用、人力、時\n程、風險、先決條件等評估。  \n六、資訊部門人員 組織優化需求  \n(一)現況與架構說明  \n1.組織架構  \n  \n2.資訊單位 主要職掌  \n(1) 資訊發展 策略規劃。 \n(2) 業務資訊應用系統 規劃、開發、建置與維護 。 \n(3) 資訊基礎設施與資源規劃、開發、建置與維護 。 \n(4) 資訊安全與個資保護 。 \n(5) 資訊系統委外作業管理 。 處長\n副處長\n系統作業科\n備援管理股\n連線管理股\n資訊處理股\n系統操作股系統管理科\n資訊安全\n股\n開放系統\n股\n系統程式\n股郵務資訊科\n營業資訊\n股\n郵遞資訊\n股電子資訊科\n管理資訊\n股\n業務資訊\n股\n電子商務\n股財金資訊科\n財務資訊\n股\n匯兌壽險\n股\n儲金劃撥\n股綜合規劃科\n資訊行政股\n資訊治理\n股\n資訊規劃\n股專門委員\n資安管理師', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 22}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n21  \n交通部中華郵政股份有限公司  \n3.資訊系統委外廠商管理機制  \n本公司目前訂 相關管理 規範作為委外辦理資通系統開發與\n維護之依據，內容包含受託廠商簽訂契約之安全要求、受託\n廠商存取風險評估、委外服務人員管理、受託廠商服務交付\n管理及受託廠商履約能力管理等。  \n(二)檢視與評估需求  \n1.提供強化資訊系統委外監督及委外廠商管理機制具體建議\n及作法: \n得標廠商 應就目前本公司委外管理現況，綜合評估相關營\n運交易成本、競爭對手作法等面向，提供具體建議及作\n法，說明如何強化資訊系統委外監督及委外廠商管理機\n制，以降低資訊作業異常風險。  \n2.檢視及規劃資訊處組織架構 : \n因應本公司未來業務數位轉型與多元化經營之發展目標，\n檢視本公司資訊處現行組織架構及人力配置，並參考同業\n實務經驗，規劃本公司資訊處人員組織架構未來藍圖。  \n(1) 未來組織架構藍圖  \n(2) 各科及人員功能、所需技能及人力配置  \n(3) 未來組織業務運作流程  \n(4) 現行與未來組織架構差異分析  \n(5) 組織轉換階段性準則及細部計畫  \n3.職能培育相關工作 : \n依據每一職位所需技能，建議相關教育訓練課程清單，以\n協助建立每個功能職位應具備的技能  \n4.所提建議應提供配合現有組織及環境下的短期方案，及完\n整改善之長期方案，且各方案均應有其效益分析說明 (可\n量化效益為佳 )。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 23}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n22  \n交通部中華郵政股份有限公司  \n5.因應本公司現況與差異，提供實現 各最佳化方案建議之費\n用、人力、時程、風險、先決條件等評估。  \n七、報告說明會需求  \n(一)本案範圍各領域訪談完成後 ，應於期限內 交付「資訊現況報\n告書」，送交本公司審核認可， 並於報告書核可後 14日內辦\n理「資訊現況 簡報說明 」。 \n(二)完成分析與建議作業後 ，應於期限內交付 「資訊整體架構優\n化建議報告書 」，送交本公司審核認可，並於 建議報告書審核\n認可次日起 14日內辦理「專案總結 簡報」。 \n八、專案品質保證需求  \n(一) 品質控制  \n為控制本專案各項產出及交付項目的品質，得標廠商的品質\n控制規劃作業，應包含缺失預防規劃、缺失識別規劃、缺失\n矯正規劃。  \n(二)品質保證  \n得標廠商須建立機制以保證本專案各項活動、產出及交付項\n目符合本文件的要求及建議書的規劃承諾。  \n九、專案資安需求  \n本專案進行期間所有相關人員、活動，須依循本公司資安規範、\n保密協定及個人資料保護等相關 規定(相關文件，於得標廠商簽約\n後提供參閱 )。 \n十、專案組織與管理需求  \n投標廠商須於建議書中 說明針對本專案擬 建立之專案組織架構、\n專案管理運作方式、 執行之工作 項目、時程規劃及檢查時間點', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 24}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n23  \n交通部中華郵政股份有限公司  \n(check point) 等。 \n(一)專案組織  \n1. 投標廠商 (分包廠商列入採計 )應提出資訊策略 、 組織及 系統\n架構健檢與規劃 專業能力 之相關完工經驗說明 (以國內金融\n業為優)。 \n2. 參與本專案之專案 成員須為廠商 (含分包廠商 )之正式員工，\n並應說明 於本專案組織 之角色且須涵蓋下列項目： \n(1) 專案經理 具備以下認證：  \n➢ 國際專案管理師 (Project Management Professional)\n認證。 \n➢ ITIL Foundation 認證。 \n(2) 資訊管理流程顧問 (具資安系統專案認 證(CISSP)、\nISO27001 、ISO20000 、ISO22301 主導稽核員、國際電腦\n稽核師(CISA)為優)。 \n(3) 人力資源相關領域 3年以上經驗顧問。 (具備相關證照\n為優)  \n(4) 大型主機 (Mainframe) 之作業系統 (z/OS)、子系統 (IMS \nDC/DB、MQ等)、程式語言 (PL/I、COBOL)等相關領域 3\n年以上經驗專業人員。 (具備CAP、CICS及Assembly 語\n言經驗人員為優 ) \n(5) 伺服器與磁碟儲存體 等相關領域 3年以上經驗專業人\n員。(具備相關證照為優 ) \n(6) 虛擬伺服器、作業系統 (Window 及Linux)、MS SQL資\n料庫等相關領域 3年以上經驗專業人員 。(具備相關證\n照為優) \n(7) 網路、防火牆、 IPS、阻斷式攻擊防護 (DDoS) 及流量負\n載平衡設備 等相關領域 3年以上經驗專業人員。 (具備\n相關證照 及防毒軟體、 APT、DLP、SOC專業人員 為優)', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 25}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n24  \n交通部中華郵政股份有限公司  \n(8) 機房環境規劃與建置等相關領域 3年以上經驗專業人\n員。 \n(9) 應用系統分析及程式設計(至少應含 .NET C# 、JAVA等\n語言)相關領域3年以上經驗專業人員 (具備相關證照\n及.NET VB、VB、PowerBuilder 經驗為優)。 \n3. 說明預計投入本專案之人數、組織架構、職責分工、人力配\n置與人員學經歷 、技術專長。  \n4. 專案組織編組、 職責與成員名單應詳列於工作說明書 ，工作\n說明書所列專案組織成員 名單如與投標時建議書內所列不\n一致，應敘明理由並須經 本公司核可；惟專案經理 或資訊管\n理流程顧問 每異動1人分別計罰違約金新臺幣 20萬元整，\n其餘成員每異動1人計罰違約金新臺幣 5萬元整。  \n5. 工作說明書所列專案組織成員經本公司認可後 ，於契約期間，\n人員異動應敘明理由並須於異動 2週前經甲方核可 。 \n6. 專案經理 及資訊管理流程顧問 於專案期間不得異動 ， 如有異\n動，每1人計罰違約金新臺幣 20萬元整； 其餘成員 於專案\n期間異動不得超過其人員總數額 1/5（小數無條件捨去） ，\n如有異動超過 1/5（小數無條件捨去） ，超過後每 1人計罰\n新臺幣5萬元。惟依本公司要求更換者，不在此限。  \n7. 本公司如認為參與本專案之人員不符合執行本專案之需求 ，\n得要求廠商於1個月內更換專案成員並經 本公司核可，得\n標廠商不得拒絕。如未依期限完成人員更換並經 本公司核可，\n自逾更換期限次日起， 每人每逾1日計罰逾期違約金 新臺\n幣1萬元。 \n8. 上述各項人員異動應敘明理由 ，遇計罰狀況時 ，除因死亡、\n因病須住院 1星期以上、因天災事變無法繼續工作者 (前述\n事項均須檢附證明且經 本公司核可)，或依本公司要求更換\n者得不予計罰外，其餘原因之人員異動縱經 本公司核可，仍\n應予以計罰。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 26}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n25  \n交通部中華郵政股份有限公司  \n(二)專案管理  \n1. 專案工作規劃  \n說明專案工作範圍、執行專案工作項目、 時程規劃、 專案執\n行策略、專案啟動會議及各式定期或不定期會議、 以及專案\n進行過程中所建立之執行與管制紀錄。  \n2. 專案風險管制 \n專案進行期間，對於專案應預先提出專案可能之風險，針對\n專案可能之風險應提出有效因應方式 ， 對專案進度與品質應\n建立監控方法，以期有效解決問題與異常狀況，並明確說明\n雙方應配合與協調之事實。  \n3. 專案狀態報告  \n自開工日次月起每月交 付本專案前 1個月之專案狀態報告\n(得以會議方式辦理 )， 專案狀態報告內容 依專案執行情形可\n包括： \n(1) 執行進度： 說明各工作項目 執行內容及完成的進度百分\n比。 \n(2) 問題解決或矯正進度 與紀錄。 \n(3) 風險管理紀錄。  \n(4) 品質控制報告：包含文件驗證審查、系統程式測試之度\n量分析報告。  \n(5) 專案規模變化報告：包括規模重估算及需求變更產生的\n規模變化。  \n十一、分包管理需求  \n本專案之專案管理 應由得標廠商 自行履行，不得 轉包。得標廠商\n如果採取分包方式執行本專案其他各項活動，必須於建議書界定\n下列事項：  \n(一)作業分工', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 27}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n26  \n交通部中華郵政股份有限公司  \n說明得標廠商 與分包商的作業分工及權責內容，作業分工說\n明，必須分別依工作事項劃分 及依專案生命週期劃分 兩個部\n分進行說明。  \n(二)溝通介面 及方法 \n說明得標廠商 與分包商在專案生命週期各階段作業分工活動\n相依性及協調事項，對於每一項相依活動，都必須說明活動\n負責人、溝通方法 及溝通管理。  \n十二、專案稽核需求  \n(一) 本公司得視本專案之執行狀況，對得標廠商提出外部稽核要\n求，由本公司指派人員不定期 (須事先知會日期 )，至得標廠\n商執行本專案之辦公室或地點，執行稽核活動 ，以了解得標\n廠商是否依照本文件要求、投標建議書及專案規劃文件的承\n諾，執行本專案各項活動，得標廠商不得拒絕。  \n(二) 本公司指派之稽核人員得要求查看 與本專案相關之所有文\n件、紀錄 及系統設施，必要時，本公司指派人員得以訪談得\n標廠商參與本專案之人員，以了解專案成員是否具備執行本\n專案所需之技能與知識，如本公司人員認為得標廠商參與本\n專案之人員不符合執行本專案之需求，得要求 得標廠商於 1\n個月內更換專案成員，得標廠商不得拒絕。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 28}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n27  \n交通部中華郵政股份有限公司  \n十三、工作說明書需求  \n(一) 工作說明書  \n1. 得標廠商應於決標次日起 14日內依建議書徵求說明書規格\n製作「工作說明書」 ，送交本公司審核認可， 逾期交付則依\n契約規定計罰逾期違約金 ， 本公司以建議書徵求說明書及得\n標廠商提供之建議書為審查之依據。若該「工作說明書」未\n經本公司認可時，得標廠商須重新修改，修改次數以 2次為\n限，若決標次日起 60日內無法通過本公司認可，以違約論，\n本公司得 終止或解除契約並沒收保證金 ， 並依政府採購法第\n101條至第103條之規定處理。  \n2. 工作說明書應包括下列內容：  \n第一章   概述 \n第二章   工作範圍  \n第三章   各階段專案管理 及時程控管 計畫 \n第四章   訪談計畫說明  \n第五章   交付文件網要  \n第六章   專案工作時程  \n第七章   專案人員編組與職責  \n第八章   驗收準則  \n(1) 驗收項目  \n(2) 驗證方法 \n(3) 驗收時程  \n(4) 驗收環境 \n(5) 驗收人力 \n第九章   簡報計畫 \n第十章   各階段品質保證計畫', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 29}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n28  \n交通部中華郵政股份有限公司  \n柒、驗收準則  \n一、文件驗證準則  \n(二) 得標廠商所交付之文件，經本公司審查後，如無發現嚴重缺失\n或中度缺失，且 80%之輕度缺失已經矯正完畢，本公司得逕行\n辦理驗收。  \n(三) 得標廠商交付之程式，經 本公司驗收測試後，如無發現嚴重缺\n失或中度缺失，且 90%之輕度缺失已經矯正完畢，本公司得逕\n行辦理驗收。  \n(四) 驗收時未矯正完成之文件缺失 或程式缺失，應於系統完成驗收\n之次日起 30天內完成矯正，且須送經本公司確認。逾期未矯\n正完成，每逾 1日依契約罰則規定計罰逾期違約金。  \n二、驗收審查準則  \n(一) 得標廠商於各階段交付之文件報告將由本公司以召開審查會\n議方式針對其合理性及可用性等面向進行確認。  \n(二) 所提改善建議與方案如 為可於現有軟硬體架構下的短期方案，\n本公司得依需要逕行驗測可行性與效益 等，並對實施結果逕付\n審查。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 30}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n29  \n交通部中華郵政股份有限公司  \n捌、建議書  \n一、服務建議書 製作 \n(一) 目錄及評選項目對照表  \n1. 製作建議書章節目錄。  \n2. 製作評選項目與建議書章節對照表，參考格式如下：  \n評選項目  內容說明  建議書章節頁次  \n   \n   \n   \n(二) 名詞定義與詞彙  \n(三) 資訊整體架構健檢及優化需求  \n投標廠商應就 下列本案各項需求範圍說明如何進行現況訪談，\n如何提出適合本公司之 改善建議與方案 ，如何產出與現況差\n異之分析說明，及如何規劃實現 改善建議與方案 之前題與所\n需資源，內容包括進行方式、參與人員、使用工具或理論、 各\n作業優先順序、 規劃時程、報告大網等。  \n1.資訊硬體及系統軟體  \n2.資訊安全  \n3.機房環境。  \n4.軟體開發。  \n5.資訊服務支援業務發展。  \n6.資訊部門人員組織。  \n(四) 品質保證  \n說明達成品質需求的各種品管計畫。例如：方法論、工作程\n序、標準、工具及技巧 等。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 31}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n30  \n交通部中華郵政股份有限公司  \n(五) 資訊安全管理  \n說明為維護本專案系統的正常運作、確保資訊傳輸交易安\n全，並保障處理資料之機密性與完整性，投標廠商針對參與\n本專案之人員及本專案系統所採取的資訊安全措施及方案。\n內容至少包含：  \n人員安全管理及教育訓練方案、電腦病毒及惡意軟體之防範\n措施、作業權限與帳號管理方案、系統存取控制方案、媒體\n及文件之安全管理措施、病毒或惡意程式入侵的事後處理程\n序等。  \n(六) 簡報計畫 \n說明至少滿足本說明書需求各 階段簡報之內容概述 、辦理方\n式及時數等。 \n(七) 公司簡介 \n說明廠商之基本資 料(含成立時間、資本額 )、財務報表 (含\n近3年營業額、營業淨利 )、人力資源 、技術能力及針對本\n專案所要求技術支援、顧問及諮詢服務 能力。  \n(八) 專案組織及成員  \n1. 說明參與本專案之組織結構、分工、人力配置及成員具備\n之學經歷證照等。  \n2. 工作人員履歷表：  \n說明參與本專案工作人員的資歷，以供審查能力是否適合\n擔任本專案指派工作。其內容應包括姓名、本專案擔任之工\n作職稱、目前工作職稱及在公司服務年資、教育程度、資訊\n工作年資、參與類似專案經驗。相關經驗應註明所參與之專\n案名稱、專案性質、參與專案起訖時間、專案中負責工作。  \n3. 參與本專案人員之資歷，請以每人一頁方式依下表格式說\n明(須檢附投保資料表 (明細)影本)：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 32}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n31  \n交通部中華郵政股份有限公司  \n姓名  最高學歷   \n現任公司職稱   服務公司年資   \n擔任本專案之\n工作職稱   擔任本專案工作\n職稱之年資   \n類似專案經驗  專案名稱  專案性質  負責工作  起訖日期  \n    \n    \n主要專業證照名稱  取得日期  \n  \n(九) 公司相類似工作經驗與履約紀錄  \n投標廠商針對本專案所建議 範圍，列表說明最近 5年(含)內\n曾承包過 相類似工作經驗 之專案，並提供書面證明 (契約書\n或完工證明文件 等；所附文件須可供審查 履約績效 之內\n容)。 \n(十) 專案管理  \n投標廠商須說明針對 本專案之專案管理 (包含專案工作規\n劃、專案風險管制及專案狀態報告 )運作方式 、執行工作項\n目、時程規劃 及檢查時間點 等。 \n(十一)分包管理 \n就投標廠商自行履約及分包項目提出說明，並界定作業分工\n模式及溝通介面 及方法。  \n二、價格建議書 製作  \n(一) 報價及價格分析：  \n投標廠商應依所提建議書所列各項 需求項目，分別以新臺幣\n報價。報價時，應提出「總價及分項報價表」與「分項 明細\n表」 ，並就所提各項價格依各工作項目所需各類人員之人\n力、時間及薪資作價格分析，以為價格審查之參考。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 33}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n32  \n交通部中華郵政股份有限公司  \n1. 總價及分項報價表：  \n所報總價及分項報價表必須完整，不得以任何理由要求變\n更價格、發還押標金或退回所投建議書。  \n2. 分項明細表：  \n(1) 各工作項目所需成本價格及 合計總價 。 \n(2) 說明文件： 所有報告及說明文件分項列出其價格。  \n(3) 管理費用：列出該計畫相關之各項管理費用。管理費\n用參照『 機關委託資訊服務廠商評選及計費辦法 』規\n定。 \n(4) 支援服務：列出各項支援服務項目及總價格。  \n(5) 其他。 \n(二) 參考資料：  \n提出本價格建議參考資料，包括成本或價格資料、影響成本\n或價格之事實陳述、現有成本及計價之證明。  \n三、建議書製 作規則(詳招標規範 ) \n四、建議書評選辦法 (詳招標規範 )', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 34})]

# %%
len(pages)
# Out:
# 35

# %% [markdown]
# #### RAG

# %% [markdown]
# Import packages

# %%
from langchain_community.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_openai import OpenAI, OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[68], line 5
#       3 from langchain_core.prompts import ChatPromptTemplate
#       4 from langchain_core.runnables import RunnableLambda, RunnablePassthrough
# ----> 5 from langchain.runnables import ValuePassthrough
#       6 from langchain_openai import OpenAI, OpenAIEmbeddings
#       7 from langchain_pinecone import PineconeVectorStore
#
# ImportError: cannot import name 'ValuePassthrough' from 'langchain.runnables' (/home/cch1006/langchain-knowledge-graph/venv/lib/python3.10/site-packages/langchain/runnables/__init__.py)

# %% [markdown]
# Split the character using RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
documents = text_splitter.split_documents(pages)
embeddings = OpenAIEmbeddings()
documents
# Out:
# [Document(page_content='資訊整體架構健檢及優化服務\n專案 \n建議書徵求說明書  \n(Request for Proposal )  \n \n \n \n \n \n \n \n108年11月25日\n交通部中華郵政股份有限公司', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 0}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \nI \n交通部中華郵政股份有限公司  \n目錄  \n壹、 概述  ................................ ................................ ................................ ....................  1', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='一、  專案緣起  ................................ ................................ ................................ ...............................  1', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='二、  專案目標  ................................ ................................ ................................ ...............................  1', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='貳、 文件詞彙與用語  ................................ ................................ ................................  2', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='一、  名詞定義  ................................ ................................ ................................ ...............................  2', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='二、  文件用語  ................................ ................................ ................................ ...............................  4', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='參、  專案說明  ................................ ................................ ................................ ............  5', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='一、  專案名稱  ................................ ................................ ................................ ...............................  5', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='二、  專案範圍  ................................ ................................ ................................ ...............................  5', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='三、  專案時程  ................................ ................................ ................................ ...............................  5', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='肆、  交付項目及時程  ................................ ................................ ................................  6', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='一、  交付項目與時程  ................................ ................................ ................................ ...................  6', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='................................ ................................ ................................ ................................ .........................  6', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='二、  交付方法與數量  ................................ ................................ ................................ ...................  6', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='伍、  資訊系統整體架構現況說明  ................................ ................................ ............  7', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='一、  系統軟硬體環境說明  ................................ ................................ ................................ ...........  7', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='陸、  專案需求  ................................ ................................ ................................ ............  9', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='一、  資訊硬體及系統軟體優化需求  ................................ ................................ ...........................  9', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='二、  資訊安全架構與管理機制優化需求  ................................ ................................ .................  14', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='三、 資訊處雙中心機房環境優化需求  ................................ ................................ .....................  16', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='四、  應用軟體開發優化需求  ................................ ................................ ................................ ..... 17', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='五、  資訊服務對業務發展支援的優化需求  ................................ ................................ .............  19', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='六、  資訊部門人員組織優化需求  ................................ ................................ .............................  20', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='七、 報告說明會需求  ................................ ................................ ................................ .................  22', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='八、 專案品質保證需求  ................................ ................................ ................................ .............  22', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='九、  專案資安需求  ................................ ................................ ................................ .....................  22', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='十、  專案組織與管理需求  ................................ ................................ ................................ .........  22', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='十一、  分包管理需求  ................................ ................................ ................................ .................  25', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 1}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \nII  \n交通部中華郵政股份有限公司  \n十二、  專案稽核需求  ................................ ................................ ................................ .................  26', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='十三、  工作說明書需求  ................................ ................................ ................................ .............  27', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='柒、  驗收準則  ................................ ................................ ................................ ..........  28', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='一、  文件驗證準則  ................................ ................................ ................................ .....................  28', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='二、  驗收審查準則  ................................ ................................ ................................ .....................  28', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='捌、  建議書  ................................ ................................ ................................ ..............  29', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='一、  服務建議書製作  ................................ ................................ ................................ .................  29', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='二、  價格建議書製作  ................................ ................................ ................................ .................  31', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='三、  建議書製 作規則(詳招標規範 ) ................................ ................................ .........................  32', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='四、 建議書評選辦法 (詳招標規範 ) ................................ ................................ .........................  32', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 2}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n1 \n交通部中華郵政股份有限公司  \n壹、概述 \n一、專案緣起 \n鑑於本公司業務對於資訊系統依賴度不斷增加，另考量未來通路\n與電子支付 發展趨勢，無論由實體到虛擬，由支局到網路再到雲\n端，甚至於電子行動業務，要求 7x24小時不中斷服務作業的壓力\n與日俱增；爰透過 第三方專業諮詢團隊針對本公司資訊整體架構', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 3}),
#  Document(page_content='進行健檢 ，並提出 優化方向與方案建議 ，以強化資訊作業品質，\n降低資訊作業風險，提升資訊組織效率，提供顧客穩定、安全及\n優質金融資訊服務，進而提升 公司營運綜效及創造企業價值。  \n二、專案目標  \n(一) 蒐集並查訪本公司資訊軟硬體架構與管理現況，確認目前資訊\n服務提供情形，並據以分析資訊整體架構 及運作流程 ，提供各\n面向優化方案。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 3}),
#  Document(page_content='面向優化方案。  \n(二) 評估並提出適合本公司資訊作業 各面向的 改善建議與方案 ，以\n提供符合本公司經營策略與業務需求且具持續改善能力之服\n務導向資訊變革依據 ，俾強化本公司資訊服務能力，提升服務\n品質，達到降低資訊異常發生頻率、提高資訊 系統運作效能並\n提升資訊 作業維運效率目標 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 3}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n2  \n交通部中華郵政股份有限公司  \n貳、文件詞彙與用語  \n一、名詞定義  \n(一) 開工日 \n係指召開本專案開工會議 (Kick-off Meeting) 當日。 \n(二) 缺失 \n與標準或需求有所不同或不一致的部分稱為缺失\n（Defect） ，本文件中「缺失」用語包含文件中的缺失及程', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 4}),
#  Document(page_content='式缺失（ Bug） 。程式缺失包括平臺 軟體功能、操作、畫面、\n效能、資訊安全等軟體開發或管理上之預料外行為。缺失可\n以依照其屬性及影響程度，給予不同分類和權值。  \n(三) 嚴重缺失  \n嚴重缺失包含： (1)得標廠商所交付之文件，存在錯誤描\n述、遺漏描述、不符合本公司作業標準的描述或無法執行之\n描述。(2)得標廠商所交付之程式存在缺失，造成系統當機', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 4}),
#  Document(page_content='或部分系統模組無法使用。嚴重等級缺失之權值應訂為 3。 \n(四) 中度缺失  \n中度缺失包含： (1)得標廠商所交付之文件，存在不清楚或\n不足夠的描述、用語不恰當。 (2)得標廠商所交付之程式存\n在缺失，造成資料處理錯誤、部分系統功能無法使用。中度\n等級缺失之權值應訂為 2。 \n(五) 輕度缺失  \n輕度缺失包含： (1)得標廠商所交付之文件，存在編輯上的', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 4}),
#  Document(page_content='錯誤。(2)得標廠商所交付之程式存在缺失，造成系統操作\n畫面、報表呈現格式和使用者期望不一致。輕度等級缺失之\n權值應訂為 1。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 4}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n3  \n交通部中華郵政股份有限公司  \n(六) 全部缺失抑制有效性  \n全部缺失抑制有效性（ Total Defect Containment \nEffectiveness, TDCE ）是指由得標廠商所發現的文件或程\n式缺失值， 佔本專案驗證審查文件及測試時得標廠商與本公', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 5}),
#  Document(page_content='司所發現的總缺失值的比例。公式為  TDCE = I / (I+E) * \n100%，其中I是指由得標廠商發現之文件或程式缺失，經加\n權計算後的缺失值。 E是指本公司對得標廠商所交付之文件\n或程式，審查或測試所發現並經加權計算後的缺失值。  \n(七) 缺失移除效果  \n缺失移除效果 (Defect Removal Effectiveness ，DRE)是指', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 5}),
#  Document(page_content='得標廠商所交付之文件或程式，移除所有已發現缺失的數\n量，經加權計算後的缺失值， 佔本專案所有加權缺失值的比\n例。DRE=C/(O+C) ，其中， C表示所有被發現且已經 改正的缺\n失值，O表示所有被發現但還沒有 改正的缺失值。  \n(八) 加權缺失密度  \n加權缺失密度 (Weight Defect Density ，WDD)是指計算每一\n缺失依其分類對應之權值，將所有文件缺失和程式缺失分別', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 5}),
#  Document(page_content='計算其權值總和，文件缺失權值總和除以本專案執行驗證審\n查文件頁數（文件Size，文件提供方式以 Word標楷體字\n型、字大小 14、間距0行、單行行距 ）得到文件加權缺失密\n度。程式缺失權值總和除以本專案軟體規模數 (程式Size)得\n到程式加權缺失密度。假設缺失依其嚴重程度分為 A、B、C\n三類，其權值分別為 a、b、c，缺失數量為 X、Y、Z，則缺', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 5}),
#  Document(page_content='失密度為 WDD=Σ(XAa+YBb+ZCc)/Size 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 5}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n4  \n交通部中華郵政股份有限公司  \n二、文件用語  \n(一) 時程與時間  \n本文件中有關於「時程」或「時間」的要求，除另有說明或\n特別約定外，均採用日曆天為時程計算依據。例如，簽約後\n30日內完成交付，是指簽訂契約之次日起 30個日曆天 內完\n成交付。  \n(二) 交付', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 6}),
#  Document(page_content='成交付。  \n(二) 交付 \n本文件中有關於「完成交付」 、 「交付」或「完成」等用語，\n表示得標廠商所交付之服務、文件、紀錄或程式，必須要在\n本文件要求之「時程或時間」送達本公司指定單位或人員。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 6}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n5  \n交通部中華郵政股份有限公司  \n參、專案說明  \n一、專案名稱  \n資訊整體架構健檢及優化 服務專案(以下簡稱本專案 )。 \n二、專案範圍  \n本專案檢視與優化建議 範圍為本公司各項資訊 環境及作業程序，\n且至少包含以下 項目：  \n1. 資訊硬體及系統軟體 。 \n2. 資訊安全。  \n3. 機房環境。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 7}),
#  Document(page_content='3. 機房環境。  \n4. 軟體開發。  \n5. 資訊服務支援業務發展。  \n6. 資訊部門人員組織。  \n三、專案時程  \n本專案時程分 下列階段，投標廠商須於建議書專案管理規劃中詳\n述各階段時程規劃、工作內容 ： \n(一) 專案前置階段 ：決標次日起 14日內。 \n(二) 開工階段：工作說明書審核認可次日起 7日內。 \n(三) 健檢訪談階段 ：開工次日起 6個月內。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 7}),
#  Document(page_content='(四) 分析與建議階段 ：開工次日起 8個月內。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 7}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n6  \n交通部中華郵政股份有限公司  \n肆、交付項目 及時程  \n一、交付項目與時程 \n項次 活動項目  交付項目  交付時程  \n1 專案前置 階段 工作說明書  決標次日起 14日\n內 \n2 開工階段 1. 辦理開工會議交付 開工報告  \n2. 健檢及優化訪談計畫書  工作說明書審核\n認可次日起 7日\n內', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 8}),
#  Document(page_content='認可次日起 7日\n內 \n※ 第1次驗收 (里程碑) 付款20% \n3 \n健檢訪談 階段 資訊現況報告書  \n 開工次日起 4個\n月內完成 報告書\n交付，並於審核\n認可次日起 14日\n內辦理「資訊現\n況簡報說明」  \n4 1.業管單位訪談 報告書 \n2.資訊整體架構健檢報告書  開工次日起 6個\n月內完成交付  \n5 分析與建議階\n段 資訊整體架構 優化建議報告書  開工次日起 8個', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 8}),
#  Document(page_content='月內完成交付  \n專案總結簡報  資訊整體架構 優\n化建議報告書審\n核認可次日起 14\n日內辦理 \n※ 最後驗收 (里程碑) 第2次付款80% \n \n二、交付方法與數量  \n(一) 各階段交付文件應以實體書面文件及媒體檔案 (格式為MS \nWord或Open Data )各1份為之，各項報告書經 本公司認可\n後得標廠商 應另交付 10份紙本文件 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 8}),
#  Document(page_content='(二) 全案驗收時應彙整各階段交付文件，燒錄於光碟媒體，交付\n本公司。   表一、交付項目與時程表', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 8}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n7  \n交通部中華郵政股份有限公司  \n伍、資訊系統整體架構 現況說明  \n一、系統軟硬體環境說明  \n(一)  各區重要設備說明如下：  \n本公司內部網路為 3層式架構，各支局線路匯集至各連線\n設備管理機房後，再連至 臺北資訊處及臺中備援中心。  \n區 域 重要設備  說 明 \n臺北資訊處及  \n臺中備援中心  IBM大型', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 9}),
#  Document(page_content='臺中備援中心  IBM大型\n主機 為本公司郵、儲、壽等主要業務之核心系統，提供全年\n24小時連線即時服務。目前大部分邏輯分區 (LPAR)均使\n用z/OS 2.1 作業系統，其中包含 IMS、CICS、MQ等子系\n統，以及 IMS/DB、DB2等資料庫；少數邏輯分區使用 SUSE \nLinux 12 作業系統。  \n集中運算\n環境 供本公司對外及對內服務之開放系統伺服器使用，包含', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 9}),
#  Document(page_content='伺服器、磁碟陣列及儲域網路等，作業系統包括：\nWindows Server 2008 R2 、Windows Server 2012 R2 、\nRedHat Linux 6 ，並可提供 SQL 2008 、SQL 2008 R2 作\n為資料庫使用。  \n網路設備  含路由器、交換器、負載平衡設備等，並已配置 Class A \nx 1、Class B x 3組TCP/IP網段。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 9}),
#  Document(page_content='資安設備  含防火牆、入侵偵測防護系統、 WAF、防毒軟體等。  \n各連線設備管\n理機房 伺服器 含SCCM、AD、防毒等實體伺服器。  \n網路設備  含路由器、交換器等。  \n各支局 主控機 提供臨櫃工作站交易作業閘道服務，並透過內網轉送交\n易至IBM大型主機。目前作業系統使用 Windows 2008 ，\n並安裝本公司委外開發之郵儲壽終端整合平臺 、 Windows', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 9}),
#  Document(page_content='HIS Server 、SQL Server 等軟體。  \n網路設備  含路由器、交換器等，提供工作站連接內部網路使用。  \n 表二、資訊重要設備列表', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 9}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n8  \n交通部中華郵政股份有限公司  \n(二)  資訊環境 架構圖  \n1. 本公司各業務資訊服務主要由大型主機及集中運算環境伺服器協同運\n作下提供，前者主要提供郵儲壽等核心業務交易，並將資料存放於大\n型主機磁碟機上，後者則用於提供內部員工與外部使用者各種開放環\n境及網際網路應用服務，並將相關資料存放於集中運算環境儲存體與', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 10}),
#  Document(page_content='SQL資料庫。 \n2. 為有效防範各類資安攻擊行為，本公司因應不同業務屬性資訊系統及\n用途，共劃分非軍事區（ DMZ，Demilitarized Zone） 、測試區、廠商\n開發區、企業網路區、網際網路區、大型主機區及內 部網路區等多個\n不同網路區域，其間以資安設備進行控管。  \n3. 為服務廣大用郵客戶，本公司採用負載平衡設備介接多家電信業者，', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 10}),
#  Document(page_content='以提供高可用性與流量分流之網際網路 (Internet) 服務；另為連接各\n區設備及線路，本公司使用大量路由器及交換器等網路設備，並透過\n動態計算路由機制達成網路高可用性及分流等機制。  \n台中備援中心  \n圖一、資訊環境架構圖  DWDM', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 10}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n9  \n交通部中華郵政股份有限公司  \n陸、專案需求  \n一、資訊硬體及系統軟體 優化需求  \n資訊硬體及系統軟體共通需求 : \n為提升資訊服務穩定性， 得標廠商應 針對本公司 資訊硬體及系統\n軟體等資訊基礎架構、維運 與管理機制進行檢視及訪談，據以提\n供適合本公司之 改善建議與方案 ，及其與現況差異分析說明， 至', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 11}),
#  Document(page_content='少提供以下內容：  \n➢ 改善建議與方案 及其與現況差異分析說明 內容範圍至少 包含： \n⚫ 硬體架構  \n⚫ 軟體架構  \n⚫ 備援架構  \n⚫ 能量規劃  \n⚫ 監控規劃  \n⚫ 維運與管理 \n⚫ 人員配置 (含數量、資格、資歷等) \n➢ 所提建議 應提供在現有軟硬體架構下的短期方案， 及完整改善\n之長期方案 ，且各方案應 依標的特性 ，至少對降低資訊異常發', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 11}),
#  Document(page_content='生頻率、提高資訊系統運作效能 、提升資訊作業維運效率等目\n標有其效益分析 說明，並以可量化效益為佳 。 \n➢ 因應本公司現況與建議方案差異，提供實現各 改善建議與方案\n之費用、人力、時程、風險及先決條件等評估。  \n➢ 未來方向建議 。 \n \n(一)Internet 線路 \n1. 現況與架構說明：  \n本公司對外網站連線服務同時具備 多家不同電信商之網際', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 11}),
#  Document(page_content='網路資源，且 電信商均至少設置 2條線路，並利用負載平\n衡設備自動分配線路資源。 提供本公司連接網際網路環境\n(含IPv4及IPv6)能力，對外提供公司對外網站 (如網路郵\n局、e動郵局及WebATM等)連線服務，對內提供公司同仁連', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 11}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n10  \n交通部中華郵政股份有限公司  \n線至外部網路服務 (如政府網站、 Google等)使用。 \n2. 共通需求外 其他檢視與評估需求：  \n(1) 檢視本公司 Internet 線路及相關設備配置是否完善。  \n(2) 分析線路頻寬使用情形，並提供適合本公司頻寬需求及\n使用優化。  \n \n(二)負載平衡設備', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 12}),
#  Document(page_content='(二)負載平衡設備  \n1. 現況與架構說明：  \n(1) 網域名稱解析服務 (DNS)：提供本公司對外網站名稱解\n析服務，使民眾可連接至本公司網站。  \n(2) 網站負載平衡服務：提供單一系統 2臺以上伺服器之資\n源分配，避免單臺伺服器故障造成服務中斷。  \n(3) 負載平衡設備利用高可用性 (HA)技術建置，資訊隨時同\n步，當設備異常時，自動切換至 其他正常之設備。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 12}),
#  Document(page_content='2. 共通需求外其他檢視與評估需求：  \n(1) 檢視DNS網域名稱解析服務 (DNS)及網站負載平衡服務\n內容，並提供強化建議。  \n(2) 檢視負載平衡架構，提供 系統伺服器或負載平衡設備 異\n常之快速恢復方案與 架構建議。 \n \n(三)網路設備  \n1. 現況與架構說明：  \n(1) 連結本公司各項資訊作業節點，如：伺服器、資料庫、', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 12}),
#  Document(page_content='儲存體及 Mainframe 大型主機等，以提供用郵客戶本公\n司各項資訊服務。  \n(2) 本公司採 3層式網路架構，分別為雙中心 (臺北資訊\n處、臺中備援中心 )、連線設備機房、支局等 3種環境\n配置。 \n2. 共通需求外其他檢視與評估需求：  \n(1) 計畫性作業稽核優化建議 。 \n(2) 障礙排除流程優化建議 。 \n(3) 網路架構與組態優化建議 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 12}),
#  Document(page_content='(3) 網路架構與組態優化建議 。 \n(4) 委外人員與配合廠商管理流程優化建議 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 12}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n11  \n交通部中華郵政股份有限公司  \n \n(四)實體伺服器   \n1. 現況與架構說明：  \n提供虛擬伺服器所需資源，如 CPU、記憶體、網路、儲存體\n等，另提供未虛擬化之系統所需資源，如目錄服務管理系\n統、備份系統等。  \n2. 共通需求外其他檢視與評估需求：  \n光纖網路健康及效能評估、優化及管理建議。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 13}),
#  Document(page_content='(五)集中運算環境儲存體   \n1. 現況與架構說明：  \n提供開放環境各應用系統儲存空間。  \n2. 共通需求外其他檢視與評估需求：  \n儲存體架構檢視與優化。  \n \n(六)虛擬伺服器   \n1. 現況與架構說明：  \n虛擬伺服器透過 VMware vSphere 建構，提供各應用系統運\n作資源，如虛擬 CPU、記憶體、磁碟空間等。  \n2. 共通需求外其他檢視與評估需求：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 13}),
#  Document(page_content='(1) 虛擬環境健康及效能評估、優化及管理建議。  \n(2) 虛擬資料庫架構檢視與優化。  \n \n(七)中介軟體 (BlueStar 、HIS)  \n1. 現況與架構說明：  \n(1)BlueStar 伺服器：為一單一介面平臺，作為開放系統應\n用程式與大型主機系統間的溝通橋樑，透過定義方式進\n行交易資料的轉換及轉碼作業，目前使用之業務計有外\n匯看板、聯合信用卡預借現金、郵務查詢系統、網路', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 13}),
#  Document(page_content='ATM、網路郵局、交通罰款、鐵路局代售票系統及客服\n系統等業務。  \n(2)HIS伺服器：提供 BlueStar 伺服器介接主機，並進行網\n路協定轉換。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 13}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n12  \n交通部中華郵政股份有限公司  \n(3)BlueStar 與HIS伺服器皆為集中運算環境虛擬伺服器，\n可依需求動態調整配置。另透過負載平衡設備將前端交\n易分散至 多臺 BlueStar 伺服器，並透過 HIS LU Pool\n功能，將上行交易分散於多 臺HIS 伺服器上，達成分流\n及備援機制。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 14}),
#  Document(page_content='及備援機制。  \n2. 共通需求外其他檢視與評估需求：  \n(1) HIS伺服器效能評估與優化建議。  \n(2)因應SNA通訊協定相關支援產品及廠商資源較少， 提供\n與主機網路連線方式 短中長期 規劃與因應方向。 \n \n(八)SQL資料庫 \n1. 現況與架構說明：  \n本公司主要使用 SQL Server 2008 與SQL Server 2016 ，分', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 14}),
#  Document(page_content='別為多臺 實體伺服器組成叢集架構，以 提供集中運算環境\n存取資料庫服務 。 \n2. 共通需求外其他檢視與評估需求：  \n(1) 優化現行透過 SCOM即時監控系統資源 及效能之 管理機\n制。 \n(2) 須協助評估資料庫因應未來業務發展所需容量空間，或\n提供流程機制以管控現階段及未來所需容量。  \n \n(九)大型主機 (Mainframe)  \n1. 現況與架構說明：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 14}),
#  Document(page_content='1. 現況與架構說明：  \n(1) 為本公司郵、儲、壽等主要業務之核心系統，提供全年\n24小時連線即時服務。目前大部分邏輯分區 (LPAR)均\n使用z/OS 2.1 作業系統，其中包含 IMS、CICS、MQ等\n子系統，以及 IMS/DB、DB2等資料庫；少數邏輯分區使\n用SUSE Linux 12 作業系統  \n(2) 目前大型主機自成一 DMZ區，並透過 多種資安設備管控', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 14}),
#  Document(page_content='連線，以確保資訊安全。  \n2. 共通需求外其他檢視與評估需求：  \n(1) 評估大型主機 對本公司業務的適用性及未來本公司之變\n革方向。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 14}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n13  \n交通部中華郵政股份有限公司  \n(2) 須提建議方案 之相關短中長期作法。  \n \n(十)主機磁碟機  \n1. 現況與架構說明：  \n提供大型主機高可靠性及高效能的企業等級儲存環境，目\n前配置臺北 資訊處及臺中備援中心各 2臺主機磁碟機 ，並\n透過其同步 (SRDF/S) 及非同步 (SRDF/A) 抄寫機制，建構 完', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 15}),
#  Document(page_content='整之同地備援 及異地備援機制，以確保本公司業務營運資\n料完整性與正確性，保障客戶權益。  \n2. 共通需求外其他檢視與評估需求：  \n儲存體架構檢視與優化。  \n \n(十一)作業系統 (z/OS)及子系統  \n1. 現況與架構說明：  \n(1) z/OS作業系統： z/OS係專門運作於大型主機上之作業\n系統，用於提供穩定、安全且高可用性的環境。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 15}),
#  Document(page_content='(2) IMS連線交易系統：運作於 z/OS作業系統上之交易訊\n息處理系統，為本公司主要核心帳務交易系統所使用。  \n(3) CICS連線交易系統：運作於 z/OS作業系統之之交易訊\n息處理系統，為本公司郵務及會計交易系統所使用。  \n2. 共通需求外其他檢視與評估需求：  \n目前主機上作業系統、連線交易系統等相關子系統皆由本\n公司自行維運，因其相關專業技術人員養成不易，已另案', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 15}),
#  Document(page_content='由廠商提供技術支援。本案須評估現階段廠商管理方式，\n以及評估委外維運之可行性。  \n \n(十二)主機資料庫  \n1. 現況與架構說明：  \n(1) IMS資料庫： 主機上使用之階層式資料庫，為本公司主\n要帳務資料存放所在。  \n(2) DB2資料庫： 主機上使用之關聯式資料庫，為本公司郵\n務及會計資料存放所在。  \n(3) 為預防資料庫因磁碟異常或交易程式異常等原因而損', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 15}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n14  \n交通部中華郵政股份有限公司  \n毀，定時將日誌及資料庫資料備份至磁帶。亦透過大型\n主機磁碟機抄寫功能存放於臺中備援中心，如發生災害\n時，可由臺 中備援中心接手提供資料庫服務。  \n2. 共通需求外其他檢視與評估需求：  \n本案須協助評估資料庫因應未來業務發展所需容量空間，\n或提供流程機制以管控現階段及未來所需容量。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 16}),
#  Document(page_content='二、資訊安全 架構與管理機制 優化需求  \n(一)現況與架構說明：  \n    本公司現有資安設備與防護機制項目及架構如下 : \n1. 防毒軟體  \n2. 各式防火牆 \n3. 入侵偵測及防禦機制  \n4. 進階持續性威脅（ APT）攻擊防禦措施  \n5. 資料外洩防護 (Data Loss Prevention, DLP)  \n6. 電子郵件攻擊防護機制', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 16}),
#  Document(page_content='6. 電子郵件攻擊防護機制  \n7. 阻斷式攻擊防護 (DDoS)機制 \n8. 資安監控系統 (SOC) \n9. 伺服器流量負載平衡設備及寬頻管理', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 16}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n15  \n交通部中華郵政股份有限公司  \n \n(二)檢視與評估需求：  \n針對本公司資安架構、防護作為與管理機制進行檢視及訪\n談，據以 提供適合本公司之 改善建議與方案 ，及其與現況差\n異分析說明， 內容範圍至少包含 ： \n1. 硬體架構  \n2. 軟體架構  \n3. 備援架構  \n4. 能量規劃  \n5. 監控規劃', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 17}),
#  Document(page_content='4. 能量規劃  \n5. 監控規劃  \n6. 管理與維運  \n7. 同一區域 (如各DMZ區及內部網路 )之防禦機制。  \n8. 端點設備 (如周邊裝置使用 或物聯網設備管理 )管控機制。  \n9.檔案分享 (如網路芳鄰、 USB儲存體)資料安全控管架構與程\n序。 \n10.人員配置 (含數量、資格、資歷等 ) \n圖二、資安環境架構圖', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 17}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n16  \n交通部中華郵政股份有限公司  \n11.所提建議應提供在現有軟硬體架構下的短期方案，及完整\n改善之長期方案，且各方案應依標的特性，至少對降低資\n訊異常發生頻率、提高資訊系統運作效能、提升資訊作業\n維運效率等目標有其效益分析說明，並以可量化效益為\n佳。 \n12.因應本公司現況與差異，提供實現 各改善建議與方案 之費', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 18}),
#  Document(page_content='用、人力、時程、風險、先決條件等評估。  \n13.其他未來方向建議。  \n \n三、資訊處雙中心機房環境 優化需求  \n(一)現況說明：  \n1. 電力系統  \n(1) 電力系統設備維護保養由勞安單位負責 。 \n(2) 電力系統架構：雙市電或發電機連接至不斷電系統\n(UPS)。 \n2. 空調系統  \n(1) 空調系統設備維護保養由勞安單位負責 。 \n(2) UPS供電。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 18}),
#  Document(page_content='(2) UPS供電。 \n(3) 冰水及冷卻水 2種空調箱。  \n(4) 設置備援機制。  \n3. 消防系統  \n(1) 自動滅火系統。  \n(2) 手提式滅火系統。  \n(3) 極早期偵煙預警系統，偵測異常時以聲音告警。  \n4. 環境監控系統  \n(1) 溫溼度偵測，偵測異常時以聲音告警。  \n(2) 漏水偵測，偵測異常時以聲音告警。  \n(3) CCTV系統。 \n5. 門禁管制系統。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 18}),
#  Document(page_content='5. 門禁管制系統。  \n(1) 門禁異常時聲音告警。  \n(2) 人員進出視負責業務需要申請權限。  \n(3) 每半年進行權限盤點作業。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 18}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n17  \n交通部中華郵政股份有限公司  \n表三、應用系統概況表  6. 其他 \n  重要資訊設備裝設減震模組。  \n(二)檢視與評估需求：  \n提供資訊機房架構與管理 之改善建議與方案 及其與現況差異\n分析說明 。 \n所提建議應提供在現有軟硬體架構下的短期方案，及完整改\n善之長期方案，且各方案應依標的特性，至少對降低資訊異', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 19}),
#  Document(page_content='常發生頻率、提高資訊系統運作效能、提升資訊作業維運效\n率等目標有其效益分析說明，並以可量化效益為佳。  \n \n四、應用軟體開發優化需求  \n(一)現況說明：  \n1.本公司主機與開放環境應用 系統軟體 概況如下表  \n \n     系統類型  \n作業性質  主機系統套數  開放系統套數  \n客戶服務  18套 38套 \n作業管理  \n及決策支援  15套 64套 \n系統總套數  135套', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 19}),
#  Document(page_content='系統總套數  135套 \n程式總支數  253,356 支 \n \n2.主機應用系統 現況與架構說明：  \n相關應用系統開發於 IBM Mainframe 主機，使用 PL/I、\nCOBOL及Assembly( 少數系統 )等語言， 介接資料庫有 IMS \nDB及DB2，大部分以自有人力進行 系統開發及維運，少部\n分為委外作業。  \n3.開放環境應用系統 現況與架構說明：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 19}),
#  Document(page_content='本公司應用系統除部分系統分散建置於各使用單位外，其\n餘大多數系統建置於本公司開放式集中運算環境，並依應', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 19}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n18  \n交通部中華郵政股份有限公司  \n用系統類別及屬性建置於各 DMZ區(Demilitarized \nZone)。 \n開放環境應用系統維運現況可分為以下 5類，大部分為委\n外作業，少部分以自有人力進行開發 ，使用.NET C#、.NET \nVB、JAVA、VB、PowerBuilder 等程式語言：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 20}),
#  Document(page_content='(1) 主從式架構 Client-Server系統。 \n(2) 網頁式架構 Web-Based系統  \n(3) 單機版架構系統。  \n(4) 手持式裝置架構系統。  \n(5) 通訊GateWay 架構系統 (無使用者操作介面 )。 \n \n(二)主機與開放環境應用系統軟體 檢視與評估需求：  \n為強化應用系統 開發時程、品質及系統穩定度 ，應針對本公', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 20}),
#  Document(page_content='司主機與開放環境應用系統架構及運作進行檢視與訪談，並\n提供相關說明與優化建議，內容包含但不限於下列項目 : \n1. 應用系統需求蒐集流程檢視及最佳化建議。  \n2. 應用系統分析設計 (SA)流程檢視及最佳化建議。  \n3. 應用系統開發測試流程檢視及最佳化建議。  \n4. 應用系統品質保證 (QC)作業檢視及最佳化建議。  \n5. 應用系統建置後維運與程序檢視及最佳化建議。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 20}),
#  Document(page_content='6. 應用系統自有及委外人力檢視及最佳化建議。  \n7. 自有人力數量、資格、資歷與養成檢視及最佳化建議。  \n8. 其他未來方向與建議。  \n9. 所提建議應提供配合現有組織及 系統環境下的短期方\n案，及完整改善之長期方案， 且各方案應依標的特性，\n至少對降低資訊異常發生頻率、提高資訊系統運作效\n能、提升資訊作業維運效率等目標有其效益分析說明，\n並以可量化效益為佳。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 20}),
#  Document(page_content='並以可量化效益為佳。  \n10.因應本公司現況與差異，提供實現各最佳化建議方案之\n費用、人力、時程、風險、先決條件等評估。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 20}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n19  \n交通部中華郵政股份有限公司  \n五、資訊服務對業務發展支援的優化需求  \n資訊單位應負責公司資訊策略規劃 、共用資訊基礎設施與資源 之\n管理、推動資訊安全與標準、 執行資訊系統整體規劃 及辦理資訊\n系統委外作業管理 ，惟相關運作均須與 業務單位協同作業 ，故本\n案應對各業管單位 進行現況與需求訪談 ，據以提供資訊服務對業', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 21}),
#  Document(page_content='務發展支援的現況分析與優化 作法建議，需求內容包含但不限於\n下述範圍 : \n(一)瞭解本公司郵務、儲匯、壽險、集郵、電商等各業務領域策\n略目標，如數位金融、智慧物流等 ，並據以提供各資訊面向\n最佳因應作為。  \n(二)檢視本公司 業管單位資訊需求規劃 作業流程、 人力與能力 等\n現況，並據以提供業管單位在 業務資訊化時應具備的 條件、\n態度與能力之優化建議 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 21}),
#  Document(page_content='態度與能力之優化建議 。 \n(三)提出資訊單位在 組織、資源(含人力與能力資源、軟硬體設\n備資源 )、規劃、 開發能力、 作業流程等各資訊服務面向應\n具備的條件、態度 與能力之 優化建議，以因應業務資訊化的\n需求。  \n(四)提供適合本公司 各單位業務需求 使用之資訊成本與 效益評估\n方式，及資訊成本分攤作法。  \n(五)提出適合本公司 資訊單位 與業管單位 協同運作 最佳模式與流', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 21}),
#  Document(page_content='程，以支援 業務發展 及各項創新服 務。 \n(六)提供適合本公司提出跨單位業務需求、業 管單位間及業 管單\n位與資訊單位間遇意見衝突時之整合與意見協調之 最佳運作\n建議。  \n(七)提供在業務工作計畫有變或因急迫需求須改變計畫時之最佳\n應變、處理 、協調程序與作法。  \n(八)提供資訊 異常事件發生時，資訊單位與業管單位 應變、通\n報、處理與協調之最佳 程序與作法。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 21}),
#  Document(page_content='報、處理與協調之最佳 程序與作法。  \n(九)提供本公司資訊單位與業管單位 快速掌握資訊科技發展方向\n及對新技術迅速學習及應用之最佳作法與建議 。 \n(十)所提建議應提供配合現有組織及系統環境下的短期方案，及', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 21}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n20  \n交通部中華郵政股份有限公司  \n圖三、資訊組織架構圖  完整改善之長期方案，且各方案應依標的特性，至少對降低\n資訊異常發生頻率、提高資訊系統運作效能、提升資訊作業\n維運效率等目標有其效益分析說明，並以可量化效益為佳。  \n(十一)相關資訊面最佳因應作為建議與作法應考量本公司組織與', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 22}),
#  Document(page_content='定位的獨特性，及在人力取得、法令遵循、業務發展與作業\n流程上的限制 ，並提供實現 各最佳化建議之費用、人力、時\n程、風險、先決條件等評估。  \n六、資訊部門人員 組織優化需求  \n(一)現況與架構說明  \n1.組織架構  \n  \n2.資訊單位 主要職掌  \n(1) 資訊發展 策略規劃。 \n(2) 業務資訊應用系統 規劃、開發、建置與維護 。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 22}),
#  Document(page_content='(3) 資訊基礎設施與資源規劃、開發、建置與維護 。 \n(4) 資訊安全與個資保護 。 \n(5) 資訊系統委外作業管理 。 處長\n副處長\n系統作業科\n備援管理股\n連線管理股\n資訊處理股\n系統操作股系統管理科\n資訊安全\n股\n開放系統\n股\n系統程式\n股郵務資訊科\n營業資訊\n股\n郵遞資訊\n股電子資訊科\n管理資訊\n股\n業務資訊\n股\n電子商務\n股財金資訊科\n財務資訊\n股\n匯兌壽險\n股\n儲金劃撥', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 22}),
#  Document(page_content='財務資訊\n股\n匯兌壽險\n股\n儲金劃撥\n股綜合規劃科\n資訊行政股\n資訊治理\n股\n資訊規劃\n股專門委員\n資安管理師', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 22}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n21  \n交通部中華郵政股份有限公司  \n3.資訊系統委外廠商管理機制  \n本公司目前訂 相關管理 規範作為委外辦理資通系統開發與\n維護之依據，內容包含受託廠商簽訂契約之安全要求、受託\n廠商存取風險評估、委外服務人員管理、受託廠商服務交付\n管理及受託廠商履約能力管理等。  \n(二)檢視與評估需求', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 23}),
#  Document(page_content='(二)檢視與評估需求  \n1.提供強化資訊系統委外監督及委外廠商管理機制具體建議\n及作法: \n得標廠商 應就目前本公司委外管理現況，綜合評估相關營\n運交易成本、競爭對手作法等面向，提供具體建議及作\n法，說明如何強化資訊系統委外監督及委外廠商管理機\n制，以降低資訊作業異常風險。  \n2.檢視及規劃資訊處組織架構 : \n因應本公司未來業務數位轉型與多元化經營之發展目標，', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 23}),
#  Document(page_content='檢視本公司資訊處現行組織架構及人力配置，並參考同業\n實務經驗，規劃本公司資訊處人員組織架構未來藍圖。  \n(1) 未來組織架構藍圖  \n(2) 各科及人員功能、所需技能及人力配置  \n(3) 未來組織業務運作流程  \n(4) 現行與未來組織架構差異分析  \n(5) 組織轉換階段性準則及細部計畫  \n3.職能培育相關工作 : \n依據每一職位所需技能，建議相關教育訓練課程清單，以', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 23}),
#  Document(page_content='協助建立每個功能職位應具備的技能  \n4.所提建議應提供配合現有組織及環境下的短期方案，及完\n整改善之長期方案，且各方案均應有其效益分析說明 (可\n量化效益為佳 )。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 23}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n22  \n交通部中華郵政股份有限公司  \n5.因應本公司現況與差異，提供實現 各最佳化方案建議之費\n用、人力、時程、風險、先決條件等評估。  \n七、報告說明會需求  \n(一)本案範圍各領域訪談完成後 ，應於期限內 交付「資訊現況報\n告書」，送交本公司審核認可， 並於報告書核可後 14日內辦\n理「資訊現況 簡報說明 」。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 24}),
#  Document(page_content='理「資訊現況 簡報說明 」。 \n(二)完成分析與建議作業後 ，應於期限內交付 「資訊整體架構優\n化建議報告書 」，送交本公司審核認可，並於 建議報告書審核\n認可次日起 14日內辦理「專案總結 簡報」。 \n八、專案品質保證需求  \n(一) 品質控制  \n為控制本專案各項產出及交付項目的品質，得標廠商的品質\n控制規劃作業，應包含缺失預防規劃、缺失識別規劃、缺失\n矯正規劃。  \n(二)品質保證', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 24}),
#  Document(page_content='矯正規劃。  \n(二)品質保證  \n得標廠商須建立機制以保證本專案各項活動、產出及交付項\n目符合本文件的要求及建議書的規劃承諾。  \n九、專案資安需求  \n本專案進行期間所有相關人員、活動，須依循本公司資安規範、\n保密協定及個人資料保護等相關 規定(相關文件，於得標廠商簽約\n後提供參閱 )。 \n十、專案組織與管理需求  \n投標廠商須於建議書中 說明針對本專案擬 建立之專案組織架構、', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 24}),
#  Document(page_content='專案管理運作方式、 執行之工作 項目、時程規劃及檢查時間點', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 24}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n23  \n交通部中華郵政股份有限公司  \n(check point) 等。 \n(一)專案組織  \n1. 投標廠商 (分包廠商列入採計 )應提出資訊策略 、 組織及 系統\n架構健檢與規劃 專業能力 之相關完工經驗說明 (以國內金融\n業為優)。 \n2. 參與本專案之專案 成員須為廠商 (含分包廠商 )之正式員工，', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 25}),
#  Document(page_content='並應說明 於本專案組織 之角色且須涵蓋下列項目： \n(1) 專案經理 具備以下認證：  \n➢ 國際專案管理師 (Project Management Professional)\n認證。 \n➢ ITIL Foundation 認證。 \n(2) 資訊管理流程顧問 (具資安系統專案認 證(CISSP)、\nISO27001 、ISO20000 、ISO22301 主導稽核員、國際電腦', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 25}),
#  Document(page_content='稽核師(CISA)為優)。 \n(3) 人力資源相關領域 3年以上經驗顧問。 (具備相關證照\n為優)  \n(4) 大型主機 (Mainframe) 之作業系統 (z/OS)、子系統 (IMS \nDC/DB、MQ等)、程式語言 (PL/I、COBOL)等相關領域 3\n年以上經驗專業人員。 (具備CAP、CICS及Assembly 語\n言經驗人員為優 )', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 25}),
#  Document(page_content='言經驗人員為優 ) \n(5) 伺服器與磁碟儲存體 等相關領域 3年以上經驗專業人\n員。(具備相關證照為優 ) \n(6) 虛擬伺服器、作業系統 (Window 及Linux)、MS SQL資\n料庫等相關領域 3年以上經驗專業人員 。(具備相關證\n照為優) \n(7) 網路、防火牆、 IPS、阻斷式攻擊防護 (DDoS) 及流量負\n載平衡設備 等相關領域 3年以上經驗專業人員。 (具備', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 25}),
#  Document(page_content='相關證照 及防毒軟體、 APT、DLP、SOC專業人員 為優)', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 25}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n24  \n交通部中華郵政股份有限公司  \n(8) 機房環境規劃與建置等相關領域 3年以上經驗專業人\n員。 \n(9) 應用系統分析及程式設計(至少應含 .NET C# 、JAVA等\n語言)相關領域3年以上經驗專業人員 (具備相關證照\n及.NET VB、VB、PowerBuilder 經驗為優)。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 26}),
#  Document(page_content='3. 說明預計投入本專案之人數、組織架構、職責分工、人力配\n置與人員學經歷 、技術專長。  \n4. 專案組織編組、 職責與成員名單應詳列於工作說明書 ，工作\n說明書所列專案組織成員 名單如與投標時建議書內所列不\n一致，應敘明理由並須經 本公司核可；惟專案經理 或資訊管\n理流程顧問 每異動1人分別計罰違約金新臺幣 20萬元整，\n其餘成員每異動1人計罰違約金新臺幣 5萬元整。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 26}),
#  Document(page_content='5. 工作說明書所列專案組織成員經本公司認可後 ，於契約期間，\n人員異動應敘明理由並須於異動 2週前經甲方核可 。 \n6. 專案經理 及資訊管理流程顧問 於專案期間不得異動 ， 如有異\n動，每1人計罰違約金新臺幣 20萬元整； 其餘成員 於專案\n期間異動不得超過其人員總數額 1/5（小數無條件捨去） ，\n如有異動超過 1/5（小數無條件捨去） ，超過後每 1人計罰', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 26}),
#  Document(page_content='新臺幣5萬元。惟依本公司要求更換者，不在此限。  \n7. 本公司如認為參與本專案之人員不符合執行本專案之需求 ，\n得要求廠商於1個月內更換專案成員並經 本公司核可，得\n標廠商不得拒絕。如未依期限完成人員更換並經 本公司核可，\n自逾更換期限次日起， 每人每逾1日計罰逾期違約金 新臺\n幣1萬元。 \n8. 上述各項人員異動應敘明理由 ，遇計罰狀況時 ，除因死亡、', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 26}),
#  Document(page_content='因病須住院 1星期以上、因天災事變無法繼續工作者 (前述\n事項均須檢附證明且經 本公司核可)，或依本公司要求更換\n者得不予計罰外，其餘原因之人員異動縱經 本公司核可，仍\n應予以計罰。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 26}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n25  \n交通部中華郵政股份有限公司  \n(二)專案管理  \n1. 專案工作規劃  \n說明專案工作範圍、執行專案工作項目、 時程規劃、 專案執\n行策略、專案啟動會議及各式定期或不定期會議、 以及專案\n進行過程中所建立之執行與管制紀錄。  \n2. 專案風險管制 \n專案進行期間，對於專案應預先提出專案可能之風險，針對', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 27}),
#  Document(page_content='專案可能之風險應提出有效因應方式 ， 對專案進度與品質應\n建立監控方法，以期有效解決問題與異常狀況，並明確說明\n雙方應配合與協調之事實。  \n3. 專案狀態報告  \n自開工日次月起每月交 付本專案前 1個月之專案狀態報告\n(得以會議方式辦理 )， 專案狀態報告內容 依專案執行情形可\n包括： \n(1) 執行進度： 說明各工作項目 執行內容及完成的進度百分\n比。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 27}),
#  Document(page_content='比。 \n(2) 問題解決或矯正進度 與紀錄。 \n(3) 風險管理紀錄。  \n(4) 品質控制報告：包含文件驗證審查、系統程式測試之度\n量分析報告。  \n(5) 專案規模變化報告：包括規模重估算及需求變更產生的\n規模變化。  \n十一、分包管理需求  \n本專案之專案管理 應由得標廠商 自行履行，不得 轉包。得標廠商\n如果採取分包方式執行本專案其他各項活動，必須於建議書界定\n下列事項：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 27}),
#  Document(page_content='下列事項：  \n(一)作業分工', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 27}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n26  \n交通部中華郵政股份有限公司  \n說明得標廠商 與分包商的作業分工及權責內容，作業分工說\n明，必須分別依工作事項劃分 及依專案生命週期劃分 兩個部\n分進行說明。  \n(二)溝通介面 及方法 \n說明得標廠商 與分包商在專案生命週期各階段作業分工活動\n相依性及協調事項，對於每一項相依活動，都必須說明活動', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 28}),
#  Document(page_content='負責人、溝通方法 及溝通管理。  \n十二、專案稽核需求  \n(一) 本公司得視本專案之執行狀況，對得標廠商提出外部稽核要\n求，由本公司指派人員不定期 (須事先知會日期 )，至得標廠\n商執行本專案之辦公室或地點，執行稽核活動 ，以了解得標\n廠商是否依照本文件要求、投標建議書及專案規劃文件的承\n諾，執行本專案各項活動，得標廠商不得拒絕。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 28}),
#  Document(page_content='(二) 本公司指派之稽核人員得要求查看 與本專案相關之所有文\n件、紀錄 及系統設施，必要時，本公司指派人員得以訪談得\n標廠商參與本專案之人員，以了解專案成員是否具備執行本\n專案所需之技能與知識，如本公司人員認為得標廠商參與本\n專案之人員不符合執行本專案之需求，得要求 得標廠商於 1\n個月內更換專案成員，得標廠商不得拒絕。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 28}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n27  \n交通部中華郵政股份有限公司  \n十三、工作說明書需求  \n(一) 工作說明書  \n1. 得標廠商應於決標次日起 14日內依建議書徵求說明書規格\n製作「工作說明書」 ，送交本公司審核認可， 逾期交付則依\n契約規定計罰逾期違約金 ， 本公司以建議書徵求說明書及得\n標廠商提供之建議書為審查之依據。若該「工作說明書」未', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 29}),
#  Document(page_content='經本公司認可時，得標廠商須重新修改，修改次數以 2次為\n限，若決標次日起 60日內無法通過本公司認可，以違約論，\n本公司得 終止或解除契約並沒收保證金 ， 並依政府採購法第\n101條至第103條之規定處理。  \n2. 工作說明書應包括下列內容：  \n第一章   概述 \n第二章   工作範圍  \n第三章   各階段專案管理 及時程控管 計畫 \n第四章   訪談計畫說明', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 29}),
#  Document(page_content='第四章   訪談計畫說明  \n第五章   交付文件網要  \n第六章   專案工作時程  \n第七章   專案人員編組與職責  \n第八章   驗收準則  \n(1) 驗收項目  \n(2) 驗證方法 \n(3) 驗收時程  \n(4) 驗收環境 \n(5) 驗收人力 \n第九章   簡報計畫 \n第十章   各階段品質保證計畫', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 29}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n28  \n交通部中華郵政股份有限公司  \n柒、驗收準則  \n一、文件驗證準則  \n(二) 得標廠商所交付之文件，經本公司審查後，如無發現嚴重缺失\n或中度缺失，且 80%之輕度缺失已經矯正完畢，本公司得逕行\n辦理驗收。  \n(三) 得標廠商交付之程式，經 本公司驗收測試後，如無發現嚴重缺', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 30}),
#  Document(page_content='失或中度缺失，且 90%之輕度缺失已經矯正完畢，本公司得逕\n行辦理驗收。  \n(四) 驗收時未矯正完成之文件缺失 或程式缺失，應於系統完成驗收\n之次日起 30天內完成矯正，且須送經本公司確認。逾期未矯\n正完成，每逾 1日依契約罰則規定計罰逾期違約金。  \n二、驗收審查準則  \n(一) 得標廠商於各階段交付之文件報告將由本公司以召開審查會\n議方式針對其合理性及可用性等面向進行確認。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 30}),
#  Document(page_content='(二) 所提改善建議與方案如 為可於現有軟硬體架構下的短期方案，\n本公司得依需要逕行驗測可行性與效益 等，並對實施結果逕付\n審查。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 30}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n29  \n交通部中華郵政股份有限公司  \n捌、建議書  \n一、服務建議書 製作 \n(一) 目錄及評選項目對照表  \n1. 製作建議書章節目錄。  \n2. 製作評選項目與建議書章節對照表，參考格式如下：  \n評選項目  內容說明  建議書章節頁次  \n   \n   \n   \n(二) 名詞定義與詞彙', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 31}),
#  Document(page_content='(二) 名詞定義與詞彙  \n(三) 資訊整體架構健檢及優化需求  \n投標廠商應就 下列本案各項需求範圍說明如何進行現況訪談，\n如何提出適合本公司之 改善建議與方案 ，如何產出與現況差\n異之分析說明，及如何規劃實現 改善建議與方案 之前題與所\n需資源，內容包括進行方式、參與人員、使用工具或理論、 各\n作業優先順序、 規劃時程、報告大網等。  \n1.資訊硬體及系統軟體  \n2.資訊安全', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 31}),
#  Document(page_content='2.資訊安全  \n3.機房環境。  \n4.軟體開發。  \n5.資訊服務支援業務發展。  \n6.資訊部門人員組織。  \n(四) 品質保證  \n說明達成品質需求的各種品管計畫。例如：方法論、工作程\n序、標準、工具及技巧 等。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 31}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n30  \n交通部中華郵政股份有限公司  \n(五) 資訊安全管理  \n說明為維護本專案系統的正常運作、確保資訊傳輸交易安\n全，並保障處理資料之機密性與完整性，投標廠商針對參與\n本專案之人員及本專案系統所採取的資訊安全措施及方案。\n內容至少包含：  \n人員安全管理及教育訓練方案、電腦病毒及惡意軟體之防範', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 32}),
#  Document(page_content='措施、作業權限與帳號管理方案、系統存取控制方案、媒體\n及文件之安全管理措施、病毒或惡意程式入侵的事後處理程\n序等。  \n(六) 簡報計畫 \n說明至少滿足本說明書需求各 階段簡報之內容概述 、辦理方\n式及時數等。 \n(七) 公司簡介 \n說明廠商之基本資 料(含成立時間、資本額 )、財務報表 (含\n近3年營業額、營業淨利 )、人力資源 、技術能力及針對本', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 32}),
#  Document(page_content='專案所要求技術支援、顧問及諮詢服務 能力。  \n(八) 專案組織及成員  \n1. 說明參與本專案之組織結構、分工、人力配置及成員具備\n之學經歷證照等。  \n2. 工作人員履歷表：  \n說明參與本專案工作人員的資歷，以供審查能力是否適合\n擔任本專案指派工作。其內容應包括姓名、本專案擔任之工\n作職稱、目前工作職稱及在公司服務年資、教育程度、資訊\n工作年資、參與類似專案經驗。相關經驗應註明所參與之專', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 32}),
#  Document(page_content='案名稱、專案性質、參與專案起訖時間、專案中負責工作。  \n3. 參與本專案人員之資歷，請以每人一頁方式依下表格式說\n明(須檢附投保資料表 (明細)影本)：', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 32}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n31  \n交通部中華郵政股份有限公司  \n姓名  最高學歷   \n現任公司職稱   服務公司年資   \n擔任本專案之\n工作職稱   擔任本專案工作\n職稱之年資   \n類似專案經驗  專案名稱  專案性質  負責工作  起訖日期  \n    \n    \n主要專業證照名稱  取得日期  \n  \n(九) 公司相類似工作經驗與履約紀錄', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 33}),
#  Document(page_content='投標廠商針對本專案所建議 範圍，列表說明最近 5年(含)內\n曾承包過 相類似工作經驗 之專案，並提供書面證明 (契約書\n或完工證明文件 等；所附文件須可供審查 履約績效 之內\n容)。 \n(十) 專案管理  \n投標廠商須說明針對 本專案之專案管理 (包含專案工作規\n劃、專案風險管制及專案狀態報告 )運作方式 、執行工作項\n目、時程規劃 及檢查時間點 等。 \n(十一)分包管理', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 33}),
#  Document(page_content='(十一)分包管理 \n就投標廠商自行履約及分包項目提出說明，並界定作業分工\n模式及溝通介面 及方法。  \n二、價格建議書 製作  \n(一) 報價及價格分析：  \n投標廠商應依所提建議書所列各項 需求項目，分別以新臺幣\n報價。報價時，應提出「總價及分項報價表」與「分項 明細\n表」 ，並就所提各項價格依各工作項目所需各類人員之人\n力、時間及薪資作價格分析，以為價格審查之參考。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 33}),
#  Document(page_content='「資訊整體架構健檢及優化服務 專案」建議書徵求說明書   \n \n32  \n交通部中華郵政股份有限公司  \n1. 總價及分項報價表：  \n所報總價及分項報價表必須完整，不得以任何理由要求變\n更價格、發還押標金或退回所投建議書。  \n2. 分項明細表：  \n(1) 各工作項目所需成本價格及 合計總價 。 \n(2) 說明文件： 所有報告及說明文件分項列出其價格。', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 34}),
#  Document(page_content='(3) 管理費用：列出該計畫相關之各項管理費用。管理費\n用參照『 機關委託資訊服務廠商評選及計費辦法 』規\n定。 \n(4) 支援服務：列出各項支援服務項目及總價格。  \n(5) 其他。 \n(二) 參考資料：  \n提出本價格建議參考資料，包括成本或價格資料、影響成本\n或價格之事實陳述、現有成本及計價之證明。  \n三、建議書製 作規則(詳招標規範 ) \n四、建議書評選辦法 (詳招標規範 )', metadata={'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf', 'page': 34})]

# %% [markdown]
# The pdf file has 35 pages and it is is split into 160 documents

# %%
len(documents)
# Out:
# 160

# %% [markdown]
# Use Pinecone to be the vector database

# %%
index_name = os.getenv("PINECONE_INDEX_NAME")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

docsearch = PineconeVectorStore.from_documents(documents, embeddings, index_name=index_name)

# %% [markdown]
# Search for the top ten most similar document, the docs[0] has 136 words.

# %%
query = "專案範圍包括什麼項目?"
docs = docsearch.similarity_search(query, k=10)
# docs
len(docs[0].page_content)
# Out:
# 143

# %%
docs
# Out:
# [Document(page_content='二、  專案範圍  ................................ ................................ ................................ ...............................  5', metadata={'page': 1.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='二、  專案範圍  ................................ ................................ ................................ ...............................  5', metadata={'page': 1.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='專案管理運作方式、 執行之工作 項目、時程規劃及檢查時間點', metadata={'page': 24.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='專案管理運作方式、 執行之工作 項目、時程規劃及檢查時間點', metadata={'page': 24.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='投標廠商針對本專案所建議 範圍，列表說明最近 5年(含)內\n曾承包過 相類似工作經驗 之專案，並提供書面證明 (契約書\n或完工證明文件 等；所附文件須可供審查 履約績效 之內\n容)。 \n(十) 專案管理  \n投標廠商須說明針對 本專案之專案管理 (包含專案工作規\n劃、專案風險管制及專案狀態報告 )運作方式 、執行工作項\n目、時程規劃 及檢查時間點 等。 \n(十一)分包管理', metadata={'page': 33.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='投標廠商針對本專案所建議 範圍，列表說明最近 5年(含)內\n曾承包過 相類似工作經驗 之專案，並提供書面證明 (契約書\n或完工證明文件 等；所附文件須可供審查 履約績效 之內\n容)。 \n(十) 專案管理  \n投標廠商須說明針對 本專案之專案管理 (包含專案工作規\n劃、專案風險管制及專案狀態報告 )運作方式 、執行工作項\n目、時程規劃 及檢查時間點 等。 \n(十一)分包管理', metadata={'page': 33.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='3. 機房環境。  \n4. 軟體開發。  \n5. 資訊服務支援業務發展。  \n6. 資訊部門人員組織。  \n三、專案時程  \n本專案時程分 下列階段，投標廠商須於建議書專案管理規劃中詳\n述各階段時程規劃、工作內容 ： \n(一) 專案前置階段 ：決標次日起 14日內。 \n(二) 開工階段：工作說明書審核認可次日起 7日內。 \n(三) 健檢訪談階段 ：開工次日起 6個月內。', metadata={'page': 7.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='3. 機房環境。  \n4. 軟體開發。  \n5. 資訊服務支援業務發展。  \n6. 資訊部門人員組織。  \n三、專案時程  \n本專案時程分 下列階段，投標廠商須於建議書專案管理規劃中詳\n述各階段時程規劃、工作內容 ： \n(一) 專案前置階段 ：決標次日起 14日內。 \n(二) 開工階段：工作說明書審核認可次日起 7日內。 \n(三) 健檢訪談階段 ：開工次日起 6個月內。', metadata={'page': 7.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='二、  專案目標  ................................ ................................ ................................ ...............................  1', metadata={'page': 1.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'}),
#  Document(page_content='二、  專案目標  ................................ ................................ ................................ ...............................  1', metadata={'page': 1.0, 'source': 'files/中華郵政股份有限公司_資訊整體架構健檢及優化服務專案_建議書徵求說明書0420.pdf'})]

# %% [markdown]
# Use langchain to build a RAG : `prompt| model| StrOutputParser()`

# %%
template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

model = OpenAI()

chain = (prompt| model| StrOutputParser())

context = ''.join([doc.page_content for doc in docs])
chain.invoke({"context": context, "question": query})
# Out:
# 'Answer: 交通部中華郵政股份有限公司的重點是進行資訊整體架構健檢及優化服務專案，並徵求建議書 (Request for Proposal)，期望投標廠商能提出具有國內金融業經驗的資訊策略、組織及系統架構健檢與規劃專業能力，並要求專案成員為正式員工。此外，公司也設定了驗收準則，包含文件驗證準則和程式驗收準則。'

# %% [markdown]
# Instead of using Pinecone ,trying to use FAISS as vector database

# %%
vectorstore = FAISS.from_documents(documents, OpenAIEmbeddings())
retriever = vectorstore.as_retriever(k=10)

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

model = OpenAI()

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

chain.invoke("專案範圍包括什麼項目?")
# Out:
# '\nAnswer: 專案範圍包括專案管理運作方式、執行的工作項目、時程規劃及檢查時間點。'

# %% [markdown]
# #### KG

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.graphs import Neo4jGraph
import os

url = os.getenv("URL")
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")
graph = Neo4jGraph(
    url=url,
    username=username,
    password=password
)

# %%
from langchain_community.graphs.graph_document import (
    Node as BaseNode,
    Relationship as BaseRelationship,
    GraphDocument,
)
from langchain.schema import Document
from typing import List, Dict, Any, Optional
from langchain.pydantic_v1 import Field, BaseModel

class Property(BaseModel):
  """A single property consisting of key and value"""
  key: str = Field(..., description="key")
  value: str = Field(..., description="value")

class Node(BaseNode):
    properties: Optional[List[Property]] = Field(
        None, description="List of node properties")

class Relationship(BaseRelationship):
    properties: Optional[List[Property]] = Field(
        None, description="List of relationship properties"
    )

class KnowledgeGraph(BaseModel):
    """Generate a knowledge graph with entities and relationships."""
    nodes: List[Node] = Field(
        ..., description="List of nodes in the knowledge graph")
    rels: List[Relationship] = Field(
        ..., description="List of relationships in the knowledge graph"
    )

# %%
def format_property_key(s: str) -> str:
    words = s.split()
    if not words:
        return s
    first_word = words[0].lower()
    capitalized_words = [word.capitalize() for word in words[1:]]
    return "".join([first_word] + capitalized_words)

def props_to_dict(props) -> dict:
    """Convert properties to a dictionary."""
    properties = {}
    if not props:
      return properties
    for p in props: 
        properties[format_property_key(p.key)] = p.value
    return properties

def map_to_base_node(node: Node) -> BaseNode:
    """Map the KnowledgeGraph Node to the base Node."""
    properties = props_to_dict(node.properties) if node.properties else {}
    # Add name property for better Cypher statement generation
    properties["name"] = node.id.title()
    return BaseNode(
        id=node.id.title(), type=node.type.capitalize(), properties=properties
    )


def map_to_base_relationship(rel: Relationship) -> BaseRelationship:
    """Map the KnowledgeGraph Relationship to the base Relationship."""
    source = map_to_base_node(rel.source)
    target = map_to_base_node(rel.target)
    properties = props_to_dict(rel.properties) if rel.properties else {}
    return BaseRelationship(
        source=source, target=target, type=rel.type, properties=properties
    )

# %%
import os
from langchain.chains.openai_functions import (
    create_openai_fn_chain,
    create_structured_output_chain,
)
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

llm = ChatOpenAI(model="gpt-3.5-turbo-16k", temperature=0)

def get_extraction_chain(
    allowed_nodes: Optional[List[str]] = None,
    allowed_rels: Optional[List[str]] = None
    ):
    prompt = ChatPromptTemplate.from_messages(
        [(
          "system",
          f"""# Knowledge Graph Instructions for GPT-4
## 1. Overview
You are a top-tier algorithm designed for extracting information in structured formats to build a knowledge graph.
- **Nodes** represent entities and concepts. They're akin to Wikipedia nodes.
- The aim is to achieve simplicity and clarity in the knowledge graph, making it accessible for a vast audience.
## 2. Labeling Nodes
- **Consistency**: Ensure you use basic or elementary types for node labels.
  - For example, when you identify an entity representing a person, always label it as **"person"**. Avoid using more specific terms like "mathematician" or "scientist".
- **Node IDs**: Never utilize integers as node IDs. Node IDs should be names or human-readable identifiers found in the text.
{'- **Allowed Node Labels:**' + ", ".join(allowed_nodes) if allowed_nodes else ""}
{'- **Allowed Relationship Types**:' + ", ".join(allowed_rels) if allowed_rels else ""}
## 3. Handling Numerical Data and Dates
- Numerical data, like age or other related information, should be incorporated as attributes or properties of the respective nodes.
- **No Separate Nodes for Dates/Numbers**: Do not create separate nodes for dates or numerical values. Always attach them as attributes or properties of nodes.
- **Property Format**: Properties must be in a key-value format.
- **Quotation Marks**: Never use escaped single or double quotes within property values.
- **Naming Convention**: Use camelCase for property keys, e.g., `birthDate`.
## 4. Coreference Resolution
- **Maintain Entity Consistency**: When extracting entities, it's vital to ensure consistency.
If an entity, such as "John Doe", is mentioned multiple times in the text but is referred to by different names or pronouns (e.g., "Joe", "he"),
always use the most complete identifier for that entity throughout the knowledge graph. In this example, use "John Doe" as the entity ID.
Remember, the knowledge graph should be coherent and easily understandable, so maintaining consistency in entity references is crucial.
## 5. Strict Compliance
Adhere to the rules strictly. Non-compliance will result in termination.
          """),
            ("human", "Use the given format to extract information from the following input: {input}"),
            ("human", "Tip: Make sure to answer in the correct format"),
        ])
    return create_structured_output_chain(KnowledgeGraph, llm, prompt, verbose=False)

# %%
nodes_and_relations = []
def extract_and_store_graph(
    document: Document,
    nodes:Optional[List[str]] = None,
    rels:Optional[List[str]]=None) -> None:
    # Extract graph data using OpenAI functions
    extract_chain = get_extraction_chain(nodes, rels)
    # Store the chain for later use
    nodes_and_relations.append(extract_chain)
    data = extract_chain.invoke(document.page_content)['function']
    # Construct a graph document
    graph_document = GraphDocument(
      nodes = [map_to_base_node(node) for node in data.nodes],
      relationships = [map_to_base_relationship(rel) for rel in data.rels],
      source = document
    )
    # Store information into a graph
    graph.add_graph_documents([graph_document])

# %%
from tqdm import tqdm

for i, d in tqdm(enumerate(pages), total=len(pages)):
    extract_and_store_graph(d)

# %%
# Query the knowledge graph in a RAG application
from langchain.chains import GraphCypherQAChain

graph.refresh_schema()

cypher_chain = GraphCypherQAChain.from_llm(
    graph=graph,
    cypher_llm=ChatOpenAI(temperature=0, model="gpt-4"),
    qa_llm=ChatOpenAI(temperature=0, model="gpt-3.5-turbo"),
    validate_cypher=True, # Validate relationship directions
    verbose=True
)
result = cypher_chain.invoke({"query": "專案範圍包括什麼項目?"})

# %% [markdown]
# #### RAG+KG

# %%
# Query the knowledge graph in a RAG application
from langchain.chains import GraphCypherQAChain
from langchain_openai import ChatOpenAI

graph.refresh_schema()

query = "專案範圍包括什麼項目?"

cypher_chain = GraphCypherQAChain.from_llm(
    graph=graph,
    cypher_llm=ChatOpenAI(temperature=0, model="gpt-4"),
    qa_llm=ChatOpenAI(temperature=0, model="gpt-3.5-turbo"),
    validate_cypher=True, # Validate relationship directions
    verbose=True,
    return_intermediate_steps=True
)
result = cypher_chain.invoke({"query": query})

template = """Generate a new query in other words, the meaning of the following query should stay the same, you should not miss any information.
THE LANGUAGE SHOULD STAY THE SAME ,IF THE QUERY IS IN CHINESE, THE NEW QUERY SHOULD ALSO BE IN CHINESE.
{query}
"""
prompt = ChatPromptTemplate.from_template(template)
model = OpenAI()
chain = (prompt| model| StrOutputParser())

count = 0
while result["intermediate_steps"][1]["context"] == [] and count < 3:
    count += 1
    query = chain.invoke({"query": query})
    result = cypher_chain.invoke({"query": query})
result
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Project)-[:INCLUDES]->(i) RETURN p.name, i.name
# Full Context:
# [{'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '硬體架構'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '軟體架構'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '備援架構'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '能量規劃'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '監控規劃'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '管理與維運'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '同一區域之防禦機制'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '端點設備管控機制'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '檔案分享資料安全控管架構與程序'}, {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '人員配置'}]
#
# > Finished chain.
# {'query': '專案範圍包括什麼項目?',
#  'result': '專案範圍包括硬體架構, 軟體架構, 備援架構, 能量規劃, 監控規劃, 管理與維運, 同一區域之防禦機制, 端點設備管控機制, 檔案分享資料安全控管架構與程序, 以及人員配置。',
#  'intermediate_steps': [{'query': 'MATCH (p:Project)-[:INCLUDES]->(i) RETURN p.name, i.name'},
#   {'context': [{'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '硬體架構'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '軟體架構'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '備援架構'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '能量規劃'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '監控規劃'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '管理與維運'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '同一區域之防禦機制'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '端點設備管控機制'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '檔案分享資料安全控管架構與程序'},
#     {'p.name': '資訊整體架構健檢及優化服務 專案', 'i.name': '人員配置'}]}]}

# %%
from langchain_core.runnables import Runnable

class ValueRunnable(Runnable):
    def __init__(self, value):
        super().__init__() 
        self.value = value

    def invoke(self, _ , config=None):
        return self.value


vectorstore = FAISS.from_documents(documents, OpenAIEmbeddings())
retriever = vectorstore.as_retriever(k=10)

template = """Answer the question based on the following context:
{context}
Here is some additional information to answer the question:
{context_neo4j}
The context is much more important to context_neo4j.The context_neo4j is just a reference to help you answer the question.

Question: {question}
"""
prompt1 = ChatPromptTemplate.from_template(template)

model = OpenAI()

context_neo4j = ValueRunnable(result["result"])
chain = (
    {"context": retriever, "context_neo4j": context_neo4j, "question": RunnablePassthrough()}
    | prompt1
    | model
    | StrOutputParser()
)

chain.invoke(query)
# Out:
# '\nAnswer: 專案範圍包括硬體架構, 軟體架構, 備援架構, 能量規劃, 監控規劃, 管理與維運, 同一區域之防禦機制, 端點設備管控機制, 檔案分享資料安全控管架構與程序, 以及人員配置。'
